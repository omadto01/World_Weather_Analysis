# saskylakh ru
# kuche cn
# kaitangata nz
# kapaa us
# vaitupu wf
# ushuaia ar
# laguna br
# vestmanna fo
# camacha pt
# avarua ck
# saryg-sep ru
# mahon es
# vaini to
# ushuaia ar
# hobart au
# punta arenas cl
# narsaq gl
# nizhniy ingash ru
# busselton au
# cape town za
# tabou ci
# strangnas se
# dovers vc
# busselton au
# port hueneme us
# talcahuano cl
# nizhneyansk ru
# tutoia br
# saint-philippe re
# punta arenas cl
# komsomolskiy ru
# punta arenas cl
# hobart au
# cherskiy ru
# klaksvik fo
# lebu cl
# grindavik is
# harper lr
# maragogi br
# busselton au
# puerto ayora ec
# talnakh ru
# palabuhanratu id
# dikson ru
# bredasdorp za
# busselton au
# belushya guba ru
# saleaula ws
# puerto ayora ec
# dikson ru
# albany au
# arraial do cabo br
# henties bay na
# yellowknife ca
# avarua ck
# bluff nz
# qaanaaq gl
# marsh harbour bs
# usinsk ru
# albany au
# kaitangata nz
# lagoa pt
# busselton au
# busselton au
# vardo no
# kolpashevo ru
# avarua ck
# marquette us
# vuktyl ru
# longyearbyen sj
# albany au
# port alfred za
# vaini to
# fortuna us
# cairns au
# khatanga ru
# sitka us
# bluff nz
# hermanus za
# airai pw
# vaitupu wf
# merauke id
# guerrero negro mx
# mnogovershinnyy ru
# padang id
# leningradskiy ru
# richards bay za
# arica cl
# kiboga ug
# port macquarie au
# yellowknife ca
# butaritari ki
# nikolskoye ru
# sandovo ru
# kaitangata nz
# teguise es
# rikitea pf
# hobart au
# kaeo nz
# taolanaro mg
# salalah om
# cabo san lucas mx
# mahibadhoo mv
# punta arenas cl
# beruwala lk
# airai pw
# husavik is
# caravelas br
# mataura pf
# gwadar pk
# atarasquillo mx
# beaverlodge ca
# bluff nz
# busselton au
# saleaula ws
# osinniki ru
# srednekolymsk ru
# kapaa us
# airai pw
# richards bay za
# grand gaube mu
# khatanga ru
# skalistyy ru
# nikolskoye ru
# hualmay pe
# busselton au
# arraial do cabo br
# carnarvon au
# airai pw
# mar del plata ar
# richards bay za
# georgetown sh
# mataura pf
# thompson ca
# hithadhoo mv
# vaini to
# jamestown sh
# belushya guba ru
# tasiilaq gl
# bambous virieux mu
# mount gambier au
# luderitz na
# mar del plata ar
# jamestown sh
# ushuaia ar
# rikitea pf
# zeya ru
# mys shmidta ru
# bluff nz
# thompson ca
# mar del plata ar
# new norfolk au
# kaitangata nz
# santo antonio do ica br
# meiningen de
# hobart au
# csengele hu
# khatanga ru
# bredasdorp za
# puerto ayora ec
# saskylakh ru
# isangel vu
# rensvik no
# jalu ly
# amderma ru
# trelew ar
# victoria sc
# barentsburg sj
# coihaique cl
# saurimo ao
# qaqortoq gl
# iquique cl
# gueret fr
# lebu cl
# paraiso mx
# butaritari ki
# hobart au
# mataura pf
# avarua ck
# cape town za
# panzhihua cn
# bredasdorp za
# rawson ar
# hellvik no
# bredasdorp za
# barrow us
# puerto ayora ec
# port alfred za
# vila franca do campo pt
# mataura pf
# castro cl
# ushuaia ar
# illoqqortoormiut gl
# mataura pf
# hobart au
# payson us
# east london za
# victoria sc
# saurimo ao
# castro cl
# saleaula ws
# tiksi ru
# mys shmidta ru
# shchelyayur ru
# rikitea pf
# sitka us
# puerto ayora ec
# jamestown sh
# milingimbi au
# eureka us
# busselton au
# port hardy ca
# barrow us
# saint george bm
# nikolskoye ru
# stillwater us
# chuy uy
# kahului us
# avarua ck
# kapaa us
# mataura pf
# mount isa au
# ilulissat gl
# kayerkan ru
# moron mn
# saskylakh ru
# luderitz na
# ushuaia ar
# avarua ck
# rikitea pf
# rikitea pf
# palmer us
# atuona pf
# jamestown sh
# tuatapere nz
# hermanus za
# butaritari ki
# ponta do sol cv
# puerto ayora ec
# vaini to
# punta arenas cl
# mataura pf
# rikitea pf
# cape town za
# hede cn
# kemin kg
# east london za
# samalaeulu ws
# abakaliki ng
# binga cd
# broome au
# belushya guba ru
# port lincoln au
# illoqqortoormiut gl
# los llanos de aridane es
# beyneu kz
# aasiaat gl
# punta arenas cl
# nome us
# east london za
# gushikawa jp
# hilo us
# ulaanbaatar mn
# asau tv
# khatanga ru
# kodiak us
# busselton au
# quatre cocos mu
# mar del plata ar
# kaitangata nz
# itarema br
# new norfolk au
# lata sb
# shimoda jp
# uitenhage za
# longyearbyen sj
# taolanaro mg
# carnarvon au
# nelson bay au
# rawson ar
# gamba ga
# kindu cd
# kieta pg
# kavaratti in
# east london za
# hobart au
# chuy uy
# ushuaia ar
# new norfolk au
# qaanaaq gl
# butaritari ki
# hermanus za
# matagami ca
# dikson ru
# jamestown sh
# taolanaro mg
# ulaanbaatar mn
# pisco pe
# upernavik gl
# ilulissat gl
# amderma ru
# busselton au
# jubayl lb
# kenai us
# tieling cn
# san patricio mx
# klaksvik fo
# hilo us
# kodiak us
# rikitea pf
# port alfred za
# lagoa pt
# fortuna us
# kununurra au
# hasaki jp
# sur om
# vostok ru
# klaksvik fo
# atuona pf
# bintulu my
# vanavara ru
# hedaru tz
# punta arenas cl
# tasiilaq gl
# butaritari ki
# nanortalik gl
# castro cl
# coquimbo cl
# castlerea ie
# rikitea pf
# port elizabeth za
# westport ie
# atuona pf
# surt ly
# coos bay us
# nanortalik gl
# rikitea pf
# esperance au
# saint-francois gp
# punta arenas cl
# hami cn
# provideniya ru
# nizhneyansk ru
# nikolskoye ru
# pangai to
# sentyabrskiy ru
# busselton au
# kloulklubed pw
# saint-philippe re
# douglas us
# ushuaia ar
# pevek ru
# chiradzulu mw
# jamestown sh
# cidreira br
# geraldton au
# lantana us
# ushuaia ar
# shiraz ir
# busselton au
# carinhanha br
# yellowknife ca
# paamiut gl
# strezhevoy ru
# barentsburg sj
# nikolskoye ru
# ola ru
# taolanaro mg
# chapais ca
# vaini to
# nikolskoye ru
# mehamn no
# albany au
# kurchum kz
# dunedin nz
# meulaboh id
# hermanus za
# katsuura jp
# fukue jp
# vaini to
# beira mz
# kargalinskaya ru
# punta arenas cl
# ushuaia ar
# puerto ayora ec
# anadyr ru
# cayenne gf
# port blair in
# bhuj in
# puerto ayora ec
# katsuura jp
# nizhneyansk ru
# mataura pf
# vaini to
# kupang id
# sao filipe cv
# mar del plata ar
# kimbe pg
# %%
# Starting URL for Weather Map API Call.
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&AppID={weather_api_key}"
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&AppID=a94fc95fc5113126a4c4ca8fd1430351

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
import pprint

#Retrieve the following information from the API call
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
#         pprint.pprint(city_weather)
#         break
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
 #Append the city information into city_data list.
        city_data.append({"City": city.title(),
                 "Country": city_country,
                 "Lat": city_lat,
                 "Lng": city_lng,
                 "Max Temp": city_max_temp,
                 "Humidity": city_humidity,
                 "Cloudiness": city_clouds,
                 "Wind Speed": city_wind,
                 "Current Description": city_description,})
                        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | verkhoturye
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | putina
# Processing Record 4 of Set 1 | taoudenni
# Processing Record 5 of Set 1 | bredasdorp
# Processing Record 6 of Set 1 | khatanga
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | broome
# Processing Record 12 of Set 1 | carnarvon
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | upernavik
# Processing Record 15 of Set 1 | elko
# Processing Record 16 of Set 1 | vyksa
# Processing Record 17 of Set 1 | rosario oeste
# Processing Record 18 of Set 1 | saint-philippe
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | norman wells
# Processing Record 21 of Set 1 | sao filipe
# Processing Record 22 of Set 1 | saint george
# Processing Record 23 of Set 1 | luangwa
# Processing Record 24 of Set 1 | aberdeen
# Processing Record 25 of Set 1 | esperance
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | berlevag
# Processing Record 28 of Set 1 | bathsheba
# Processing Record 29 of Set 1 | ponta do sol
# Processing Record 30 of Set 1 | tawang
# Processing Record 31 of Set 1 | verkhnevilyuysk
# Processing Record 32 of Set 1 | yatou
# Processing Record 33 of Set 1 | georgetown
# Processing Record 34 of Set 1 | ashington
# Processing Record 35 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 1 | twante
# Processing Record 37 of Set 1 | manokwari
# Processing Record 38 of Set 1 | caravelas
# Processing Record 39 of Set 1 | hilo
# Processing Record 40 of Set 1 | ostrovnoy
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | east london
# Processing Record 43 of Set 1 | kapaa
# Processing Record 44 of Set 1 | berdigestyakh
# Processing Record 45 of Set 1 | majene
# Processing Record 46 of Set 1 | dikson
# Processing Record 47 of Set 1 | chokurdakh
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | along
# Processing Record 50 of Set 1 | provideniya
# Processing Record 1 of Set 2 | dingle
# Processing Record 2 of Set 2 | butaritari
# Processing Record 3 of Set 2 | nabire
# Processing Record 4 of Set 2 | ayagoz
# Processing Record 5 of Set 2 | sambava
# Processing Record 6 of Set 2 | arraial do cabo
# Processing Record 7 of Set 2 | ubinskoye
# Processing Record 8 of Set 2 | coronel
# Processing Record 9 of Set 2 | matara
# Processing Record 10 of Set 2 | wuchi
# Processing Record 11 of Set 2 | portland
# Processing Record 12 of Set 2 | englewood
# Processing Record 13 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 2 | vaini
# Processing Record 15 of Set 2 | castro
# Processing Record 16 of Set 2 | mandera
# Processing Record 17 of Set 2 | bluff
# Processing Record 18 of Set 2 | te anau
# Processing Record 19 of Set 2 | likasi
# Processing Record 20 of Set 2 | fethiye
# Processing Record 21 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 2 | hermanus
# Processing Record 23 of Set 2 | watsa
# Processing Record 24 of Set 2 | buta
# Processing Record 25 of Set 2 | qaanaaq
# Processing Record 26 of Set 2 | aginskoye
# Processing Record 27 of Set 2 | port-gentil
# Processing Record 28 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 29 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 30 of Set 2 | boyuibe
# Processing Record 31 of Set 2 | san ignacio
# Processing Record 32 of Set 2 | lucapa
# Processing Record 33 of Set 2 | chuy
# Processing Record 34 of Set 2 | ulladulla
# Processing Record 35 of Set 2 | hithadhoo
# Processing Record 36 of Set 2 | bengkulu
# Processing Record 37 of Set 2 | namibe
# Processing Record 38 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 39 of Set 2 | verkh-usugli
# Processing Record 40 of Set 2 | hobart
# Processing Record 41 of Set 2 | dakar
# Processing Record 42 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 2 | bilma
# Processing Record 44 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 2 | grand gaube
# Processing Record 46 of Set 2 | puro
# Processing Record 47 of Set 2 | nouakchott
# Processing Record 48 of Set 2 | vestmannaeyjar
# Processing Record 49 of Set 2 | ribeira grande
# Processing Record 50 of Set 2 | paita
# Processing Record 1 of Set 3 | santa isabel do rio negro
# Processing Record 2 of Set 3 | champerico
# Processing Record 3 of Set 3 | tayu
# Processing Record 4 of Set 3 | samarai
# Processing Record 5 of Set 3 | sitka
# Processing Record 6 of Set 3 | jamestown
# Processing Record 7 of Set 3 | ahipara
# Processing Record 8 of Set 3 | kattivakkam
# Processing Record 9 of Set 3 | xining
# Processing Record 10 of Set 3 | igrim
# Processing Record 11 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 12 of Set 3 | tias
# Processing Record 13 of Set 3 | flinders
# Processing Record 14 of Set 3 | wajima
# Processing Record 15 of Set 3 | ledyard
# Processing Record 16 of Set 3 | nuqui
# Processing Record 17 of Set 3 | yellowknife
# Processing Record 18 of Set 3 | mount gambier
# Processing Record 19 of Set 3 | the valley
# Processing Record 20 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 3 | taicheng
# Processing Record 22 of Set 3 | celestun
# Processing Record 23 of Set 3 | waw
# Processing Record 24 of Set 3 | nome
# Processing Record 25 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 3 | iseyin
# Processing Record 27 of Set 3 | palu
# Processing Record 28 of Set 3 | port hardy
# Processing Record 29 of Set 3 | rolim de moura
# City not found. Skipping...
# Processing Record 30 of Set 3 | azul
# Processing Record 31 of Set 3 | wattegama
# Processing Record 32 of Set 3 | pevek
# Processing Record 33 of Set 3 | mar del plata
# Processing Record 34 of Set 3 | mahebourg
# Processing Record 35 of Set 3 | bac lieu
# Processing Record 36 of Set 3 | kodiak
# Processing Record 37 of Set 3 | los llanos de aridane
# Processing Record 38 of Set 3 | salinas
# Processing Record 39 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 3 | tasiilaq
# Processing Record 41 of Set 3 | katsuura
# Processing Record 42 of Set 3 | gazanjyk
# Processing Record 43 of Set 3 | tuktoyaktuk
# Processing Record 44 of Set 3 | prado
# Processing Record 45 of Set 3 | rapid valley
# Processing Record 46 of Set 3 | yefira
# City not found. Skipping...
# Processing Record 47 of Set 3 | sao lourenco do sul
# Processing Record 48 of Set 3 | alugan
# Processing Record 49 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 1 of Set 4 | ust-kut
# Processing Record 2 of Set 4 | torbay
# Processing Record 3 of Set 4 | souillac
# Processing Record 4 of Set 4 | kothi
# Processing Record 5 of Set 4 | college
# Processing Record 6 of Set 4 | teahupoo
# Processing Record 7 of Set 4 | henderson
# Processing Record 8 of Set 4 | nanortalik
# Processing Record 9 of Set 4 | tarko-sale
# Processing Record 10 of Set 4 | wembley
# Processing Record 11 of Set 4 | luderitz
# Processing Record 12 of Set 4 | ixtapa
# Processing Record 13 of Set 4 | talnakh
# Processing Record 14 of Set 4 | punta arenas
# Processing Record 15 of Set 4 | thompson
# Processing Record 16 of Set 4 | sao joao da barra
# Processing Record 17 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 4 | karasburg
# Processing Record 19 of Set 4 | foca
# Processing Record 20 of Set 4 | mayor pablo lagerenza
# Processing Record 21 of Set 4 | new norfolk
# Processing Record 22 of Set 4 | port lincoln
# Processing Record 23 of Set 4 | carutapera
# Processing Record 24 of Set 4 | severnoye
# Processing Record 25 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 26 of Set 4 | sunamganj
# City not found. Skipping...
# Processing Record 27 of Set 4 | esmeraldas
# Processing Record 28 of Set 4 | kiri buru
# Processing Record 29 of Set 4 | devaprayag
# Processing Record 30 of Set 4 | pochutla
# Processing Record 31 of Set 4 | lebu
# Processing Record 32 of Set 4 | san rafael del sur
# Processing Record 33 of Set 4 | santa cruz de tenerife
# Processing Record 34 of Set 4 | meulaboh
# Processing Record 35 of Set 4 | moroni
# Processing Record 36 of Set 4 | severo-kurilsk
# Processing Record 37 of Set 4 | bethel
# Processing Record 38 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 39 of Set 4 | port alfred
# Processing Record 40 of Set 4 | iaciara
# Processing Record 41 of Set 4 | kruisfontein
# Processing Record 42 of Set 4 | yantal
# Processing Record 43 of Set 4 | rio grande
# Processing Record 44 of Set 4 | kalga
# Processing Record 45 of Set 4 | vao
# Processing Record 46 of Set 4 | salalah
# Processing Record 47 of Set 4 | saskylakh
# Processing Record 48 of Set 4 | esna
# Processing Record 49 of Set 4 | vostok
# Processing Record 50 of Set 4 | laguna
# Processing Record 1 of Set 5 | yar-sale
# Processing Record 2 of Set 5 | agirish
# Processing Record 3 of Set 5 | hami
# Processing Record 4 of Set 5 | roros
# Processing Record 5 of Set 5 | galgani
# City not found. Skipping...
# Processing Record 6 of Set 5 | harper
# Processing Record 7 of Set 5 | puerto escondido
# Processing Record 8 of Set 5 | henties bay
# Processing Record 9 of Set 5 | chernyy yar
# Processing Record 10 of Set 5 | fortuna
# Processing Record 11 of Set 5 | shanghai
# Processing Record 12 of Set 5 | huarmey
# Processing Record 13 of Set 5 | araouane
# Processing Record 14 of Set 5 | maceio
# Processing Record 15 of Set 5 | ust-koksa
# Processing Record 16 of Set 5 | bihoro
# Processing Record 17 of Set 5 | itarema
# Processing Record 18 of Set 5 | chernyshevskiy
# Processing Record 19 of Set 5 | havre-saint-pierre
# Processing Record 20 of Set 5 | semnan
# Processing Record 21 of Set 5 | lago da pedra
# Processing Record 22 of Set 5 | tateyama
# Processing Record 23 of Set 5 | nsanje
# Processing Record 24 of Set 5 | lodwar
# Processing Record 25 of Set 5 | pisco
# Processing Record 26 of Set 5 | hampton
# Processing Record 27 of Set 5 | komsomolskiy
# Processing Record 28 of Set 5 | vila velha
# Processing Record 29 of Set 5 | hovd
# Processing Record 30 of Set 5 | juquia
# Processing Record 31 of Set 5 | gainesville
# Processing Record 32 of Set 5 | pundaguitan
# Processing Record 33 of Set 5 | flin flon
# Processing Record 34 of Set 5 | baganga
# Processing Record 35 of Set 5 | leningradskiy
# Processing Record 36 of Set 5 | surami
# Processing Record 37 of Set 5 | nikolskoye
# Processing Record 38 of Set 5 | san cristobal
# Processing Record 39 of Set 5 | hambantota
# Processing Record 40 of Set 5 | betioky
# Processing Record 41 of Set 5 | moron
# Processing Record 42 of Set 5 | tabuk
# Processing Record 43 of Set 5 | nantucket
# Processing Record 44 of Set 5 | velingara
# Processing Record 45 of Set 5 | bubaque
# Processing Record 46 of Set 5 | mahaena
# City not found. Skipping...
# Processing Record 47 of Set 5 | hasaki
# Processing Record 48 of Set 5 | labuhan
# Processing Record 49 of Set 5 | mae sai
# Processing Record 50 of Set 5 | faanui
# Processing Record 1 of Set 6 | vangaindrano
# Processing Record 2 of Set 6 | andevoranto
# City not found. Skipping...
# Processing Record 3 of Set 6 | toora-khem
# Processing Record 4 of Set 6 | charters towers
# Processing Record 5 of Set 6 | cidreira
# Processing Record 6 of Set 6 | guamuchil
# Processing Record 7 of Set 6 | namie
# Processing Record 8 of Set 6 | codrington
# Processing Record 9 of Set 6 | santa marta
# Processing Record 10 of Set 6 | san lorenzo
# Processing Record 11 of Set 6 | ilulissat
# Processing Record 12 of Set 6 | tolaga bay
# Processing Record 13 of Set 6 | candelaria
# Processing Record 14 of Set 6 | aklavik
# Processing Record 15 of Set 6 | yamoto
# Processing Record 16 of Set 6 | bambous virieux
# Processing Record 17 of Set 6 | nouadhibou
# Processing Record 18 of Set 6 | shingu
# Processing Record 19 of Set 6 | cherskiy
# Processing Record 20 of Set 6 | monrovia
# Processing Record 21 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 22 of Set 6 | hualmay
# Processing Record 23 of Set 6 | tshela
# Processing Record 24 of Set 6 | jacareacanga
# Processing Record 25 of Set 6 | klaksvik
# Processing Record 26 of Set 6 | barrow
# Processing Record 27 of Set 6 | terrace
# Processing Record 28 of Set 6 | kahului
# Processing Record 29 of Set 6 | orumiyeh
# Processing Record 30 of Set 6 | phirangipuram
# Processing Record 31 of Set 6 | yermekeyevo
# Processing Record 32 of Set 6 | siocon
# Processing Record 33 of Set 6 | necochea
# Processing Record 34 of Set 6 | sao felix do xingu
# Processing Record 35 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 6 | puerto leguizamo
# Processing Record 37 of Set 6 | mana
# Processing Record 38 of Set 6 | ondjiva
# Processing Record 39 of Set 6 | sola
# Processing Record 40 of Set 6 | kurya
# Processing Record 41 of Set 6 | montmagny
# Processing Record 42 of Set 6 | oriximina
# Processing Record 43 of Set 6 | kyzyl-suu
# Processing Record 44 of Set 6 | delbruck
# Processing Record 45 of Set 6 | port macquarie
# Processing Record 46 of Set 6 | liverpool
# Processing Record 47 of Set 6 | tahta
# Processing Record 48 of Set 6 | barberton
# Processing Record 49 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 7 | chabahar
# Processing Record 2 of Set 7 | karratha
# Processing Record 3 of Set 7 | puerto padre
# Processing Record 4 of Set 7 | mitu
# Processing Record 5 of Set 7 | asfi
# Processing Record 6 of Set 7 | puerto ayora
# Processing Record 7 of Set 7 | tiksi
# Processing Record 8 of Set 7 | victoria
# Processing Record 9 of Set 7 | quatre cocos
# Processing Record 10 of Set 7 | tazovskiy
# Processing Record 11 of Set 7 | proddatur
# Processing Record 12 of Set 7 | port elizabeth
# Processing Record 13 of Set 7 | richard toll
# City not found. Skipping...
# Processing Record 14 of Set 7 | mayna
# Processing Record 15 of Set 7 | harrisburg
# Processing Record 16 of Set 7 | rettikhovka
# Processing Record 17 of Set 7 | isangel
# Processing Record 18 of Set 7 | finnsnes
# Processing Record 19 of Set 7 | paragominas
# Processing Record 20 of Set 7 | iqaluit
# Processing Record 21 of Set 7 | jalingo
# Processing Record 22 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 7 | timaru
# Processing Record 24 of Set 7 | umm kaddadah
# Processing Record 25 of Set 7 | bairiki
# Processing Record 26 of Set 7 | imbituba
# Processing Record 27 of Set 7 | myrtle beach
# Processing Record 28 of Set 7 | iquique
# Processing Record 29 of Set 7 | portoferraio
# Processing Record 30 of Set 7 | hofn
# Processing Record 31 of Set 7 | fairbanks
# Processing Record 32 of Set 7 | clyde river
# Processing Record 33 of Set 7 | nemuro
# Processing Record 34 of Set 7 | valvedditturai
# Processing Record 35 of Set 7 | sohag
# Processing Record 36 of Set 7 | fairhope
# Processing Record 37 of Set 7 | manjacaze
# Processing Record 38 of Set 7 | waingapu
# Processing Record 39 of Set 7 | muisne
# Processing Record 40 of Set 7 | pyu
# Processing Record 41 of Set 7 | santa cruz
# Processing Record 42 of Set 7 | constitucion
# Processing Record 43 of Set 7 | vereeniging
# Processing Record 44 of Set 7 | yumen
# Processing Record 45 of Set 7 | mananara
# Processing Record 46 of Set 7 | kangaatsiaq
# Processing Record 47 of Set 7 | padang
# Processing Record 48 of Set 7 | semey
# Processing Record 49 of Set 7 | concordia
# Processing Record 50 of Set 7 | saint-joseph
# Processing Record 1 of Set 8 | half moon bay
# Processing Record 2 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 3 of Set 8 | karasjok
# Processing Record 4 of Set 8 | gravdal
# Processing Record 5 of Set 8 | chapais
# Processing Record 6 of Set 8 | cayenne
# Processing Record 7 of Set 8 | kondinskoye
# Processing Record 8 of Set 8 | ewo
# Processing Record 9 of Set 8 | onega
# Processing Record 10 of Set 8 | la macarena
# Processing Record 11 of Set 8 | cabedelo
# Processing Record 12 of Set 8 | ishim
# Processing Record 13 of Set 8 | richards bay
# Processing Record 14 of Set 8 | marystown
# Processing Record 15 of Set 8 | gao
# Processing Record 16 of Set 8 | dickinson
# Processing Record 17 of Set 8 | mackay
# Processing Record 18 of Set 8 | muncar
# Processing Record 19 of Set 8 | galveston
# Processing Record 20 of Set 8 | ballitoville
# Processing Record 21 of Set 8 | lasa
# Processing Record 22 of Set 8 | terra santa
# Processing Record 23 of Set 8 | gbarnga
# Processing Record 24 of Set 8 | waddan
# Processing Record 25 of Set 8 | marawi
# Processing Record 26 of Set 8 | faya
# Processing Record 27 of Set 8 | aviles
# Processing Record 28 of Set 8 | labuan
# Processing Record 29 of Set 8 | manali
# Processing Record 30 of Set 8 | kirensk
# Processing Record 31 of Set 8 | jaszkiser
# Processing Record 32 of Set 8 | el alto
# Processing Record 33 of Set 8 | kingsport
# Processing Record 34 of Set 8 | vila franca do campo
# Processing Record 35 of Set 8 | mundo nuevo
# Processing Record 36 of Set 8 | kaitangata
# Processing Record 37 of Set 8 | vestmanna
# Processing Record 38 of Set 8 | camacha
# Processing Record 39 of Set 8 | saryg-sep
# Processing Record 40 of Set 8 | mahon
# Processing Record 41 of Set 8 | narsaq
# Processing Record 42 of Set 8 | nizhniy ingash
# Processing Record 43 of Set 8 | tabou
# Processing Record 44 of Set 8 | strangnas
# Processing Record 45 of Set 8 | dovers
# Processing Record 46 of Set 8 | port hueneme
# Processing Record 47 of Set 8 | talcahuano
# Processing Record 48 of Set 8 | tutoia
# Processing Record 49 of Set 8 | grindavik
# Processing Record 50 of Set 8 | maragogi
# Processing Record 1 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 9 | marsh harbour
# Processing Record 3 of Set 9 | usinsk
# Processing Record 4 of Set 9 | lagoa
# Processing Record 5 of Set 9 | vardo
# Processing Record 6 of Set 9 | kolpashevo
# Processing Record 7 of Set 9 | marquette
# Processing Record 8 of Set 9 | vuktyl
# Processing Record 9 of Set 9 | longyearbyen
# Processing Record 10 of Set 9 | cairns
# Processing Record 11 of Set 9 | airai
# Processing Record 12 of Set 9 | merauke
# Processing Record 13 of Set 9 | guerrero negro
# Processing Record 14 of Set 9 | mnogovershinnyy
# Processing Record 15 of Set 9 | arica
# Processing Record 16 of Set 9 | kiboga
# Processing Record 17 of Set 9 | sandovo
# Processing Record 18 of Set 9 | teguise
# Processing Record 19 of Set 9 | kaeo
# Processing Record 20 of Set 9 | cabo san lucas
# Processing Record 21 of Set 9 | mahibadhoo
# Processing Record 22 of Set 9 | beruwala
# Processing Record 23 of Set 9 | husavik
# Processing Record 24 of Set 9 | gwadar
# Processing Record 25 of Set 9 | atarasquillo
# City not found. Skipping...
# Processing Record 26 of Set 9 | beaverlodge
# Processing Record 27 of Set 9 | osinniki
# Processing Record 28 of Set 9 | srednekolymsk
# Processing Record 29 of Set 9 | zeya
# Processing Record 30 of Set 9 | santo antonio do ica
# Processing Record 31 of Set 9 | meiningen
# Processing Record 32 of Set 9 | csengele
# Processing Record 33 of Set 9 | rensvik
# Processing Record 34 of Set 9 | jalu
# Processing Record 35 of Set 9 | trelew
# Processing Record 36 of Set 9 | coihaique
# Processing Record 37 of Set 9 | saurimo
# Processing Record 38 of Set 9 | qaqortoq
# Processing Record 39 of Set 9 | gueret
# Processing Record 40 of Set 9 | paraiso
# Processing Record 41 of Set 9 | panzhihua
# Processing Record 42 of Set 9 | rawson
# Processing Record 43 of Set 9 | hellvik
# Processing Record 44 of Set 9 | payson
# Processing Record 45 of Set 9 | shchelyayur
# City not found. Skipping...
# Processing Record 46 of Set 9 | milingimbi
# City not found. Skipping...
# Processing Record 47 of Set 9 | eureka
# Processing Record 48 of Set 9 | stillwater
# Processing Record 49 of Set 9 | mount isa
# Processing Record 50 of Set 9 | kayerkan
# Processing Record 1 of Set 10 | palmer
# Processing Record 2 of Set 10 | tuatapere
# Processing Record 3 of Set 10 | hede
# Processing Record 4 of Set 10 | kemin
# Processing Record 5 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 10 | abakaliki
# Processing Record 7 of Set 10 | binga
# Processing Record 8 of Set 10 | beyneu
# Processing Record 9 of Set 10 | aasiaat
# Processing Record 10 of Set 10 | gushikawa
# Processing Record 11 of Set 10 | ulaanbaatar
# Processing Record 12 of Set 10 | asau
# Processing Record 13 of Set 10 | lata
# Processing Record 14 of Set 10 | shimoda
# Processing Record 15 of Set 10 | uitenhage
# Processing Record 16 of Set 10 | nelson bay
# Processing Record 17 of Set 10 | gamba
# Processing Record 18 of Set 10 | kindu
# Processing Record 19 of Set 10 | kieta
# Processing Record 20 of Set 10 | kavaratti
# Processing Record 21 of Set 10 | matagami
# Processing Record 22 of Set 10 | jubayl
# City not found. Skipping...
# Processing Record 23 of Set 10 | kenai
# Processing Record 24 of Set 10 | tieling
# Processing Record 25 of Set 10 | san patricio
# Processing Record 26 of Set 10 | kununurra
# Processing Record 27 of Set 10 | sur
# Processing Record 28 of Set 10 | bintulu
# Processing Record 29 of Set 10 | vanavara
# Processing Record 30 of Set 10 | hedaru
# Processing Record 31 of Set 10 | coquimbo
# Processing Record 32 of Set 10 | castlerea
# Processing Record 33 of Set 10 | westport
# Processing Record 34 of Set 10 | surt
# Processing Record 35 of Set 10 | coos bay
# Processing Record 36 of Set 10 | saint-francois
# Processing Record 37 of Set 10 | pangai
# Processing Record 38 of Set 10 | kloulklubed
# Processing Record 39 of Set 10 | douglas
# Processing Record 40 of Set 10 | chiradzulu
# Processing Record 41 of Set 10 | geraldton
# Processing Record 42 of Set 10 | lantana
# Processing Record 43 of Set 10 | shiraz
# Processing Record 44 of Set 10 | carinhanha
# Processing Record 45 of Set 10 | paamiut
# Processing Record 46 of Set 10 | strezhevoy
# Processing Record 47 of Set 10 | ola
# Processing Record 48 of Set 10 | mehamn
# Processing Record 49 of Set 10 | kurchum
# Processing Record 50 of Set 10 | dunedin
# Processing Record 1 of Set 11 | fukue
# Processing Record 2 of Set 11 | beira
# Processing Record 3 of Set 11 | kargalinskaya
# Processing Record 4 of Set 11 | anadyr
# Processing Record 5 of Set 11 | port blair
# Processing Record 6 of Set 11 | bhuj
# Processing Record 7 of Set 11 | kupang
# Processing Record 8 of Set 11 | kimbe
# Processing Record 9 of Set 11 | chapleau
# Processing Record 10 of Set 11 | tezu
# Processing Record 11 of Set 11 | domoni
# Processing Record 12 of Set 11 | xuddur
# Processing Record 13 of Set 11 | altay
# Processing Record 14 of Set 11 | lantawan
# Processing Record 15 of Set 11 | pedasi
# Processing Record 16 of Set 11 | vagamo
# Processing Record 17 of Set 11 | pimentel
# Processing Record 18 of Set 11 | znamenskoye
# Processing Record 19 of Set 11 | luau
# Processing Record 20 of Set 11 | mesto albrechtice
# Processing Record 21 of Set 11 | biskamzha
# Processing Record 22 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 23 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 24 of Set 11 | iskateley
# Processing Record 25 of Set 11 | fernan-nunez
# Processing Record 26 of Set 11 | xochihuehuetlan
# Processing Record 27 of Set 11 | mangrol
# Processing Record 28 of Set 11 | cartagena del chaira
# Processing Record 29 of Set 11 | krasnogorskiy
# Processing Record 30 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 11 | ryotsu
# Processing Record 32 of Set 11 | tongren
# Processing Record 33 of Set 11 | leh
# Processing Record 34 of Set 11 | ballina
# Processing Record 35 of Set 11 | davenda
# Processing Record 36 of Set 11 | norsup
# Processing Record 37 of Set 11 | dali
# Processing Record 38 of Set 11 | margate
# Processing Record 39 of Set 11 | solnechnyy
# Processing Record 40 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 11 | juneau
# Processing Record 42 of Set 11 | olafsvik
# Processing Record 43 of Set 11 | sakaiminato
# Processing Record 44 of Set 11 | hokitika
# Processing Record 45 of Set 11 | misratah
# Processing Record 46 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 47 of Set 11 | naron
# Processing Record 48 of Set 11 | gizo
# Processing Record 49 of Set 11 | campamento
# Processing Record 50 of Set 11 | sinnamary
# Processing Record 1 of Set 12 | dianopolis
# City not found. Skipping...
# Processing Record 2 of Set 12 | graaff-reinet
# Processing Record 3 of Set 12 | awjilah
# Processing Record 4 of Set 12 | devils lake
# Processing Record 5 of Set 12 | dolores
# Processing Record 6 of Set 12 | billings
# Processing Record 7 of Set 12 | inuvik
# Processing Record 8 of Set 12 | grimshaw
# Processing Record 9 of Set 12 | progreso
# Processing Record 10 of Set 12 | saldanha
# Processing Record 11 of Set 12 | uberlandia
# Processing Record 12 of Set 12 | las vegas
# Processing Record 13 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 14 of Set 12 | manzil tamim
# City not found. Skipping...
# Processing Record 15 of Set 12 | bilibino
# Processing Record 16 of Set 12 | otofuke
# Processing Record 17 of Set 12 | saint-augustin
# Processing Record 18 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 19 of Set 12 | bouafle
# Processing Record 20 of Set 12 | korhogo
# Processing Record 21 of Set 12 | korla
# Processing Record 22 of Set 12 | manta
# Processing Record 23 of Set 12 | sao jose da coroa grande
# Processing Record 24 of Set 12 | aksha
# Processing Record 25 of Set 12 | guarapari
# Processing Record 26 of Set 12 | alta gracia
# Processing Record 27 of Set 12 | iracoubo
# Processing Record 28 of Set 12 | furukawa
# Processing Record 29 of Set 12 | ormara
# Processing Record 30 of Set 12 | viedma
# Processing Record 31 of Set 12 | wamba
# Processing Record 32 of Set 12 | alofi
# Processing Record 33 of Set 12 | beihai
# Processing Record 34 of Set 12 | mission bend
# Processing Record 35 of Set 12 | trincomalee
# Processing Record 36 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 12 | myra
# Processing Record 38 of Set 12 | hemnesberget
# Processing Record 39 of Set 12 | deputatskiy
# Processing Record 40 of Set 12 | wiarton
# Processing Record 41 of Set 12 | ouadda
# Processing Record 42 of Set 12 | paidha
# Processing Record 43 of Set 12 | brae
# Processing Record 44 of Set 12 | tekeli
# Processing Record 45 of Set 12 | valdivia
# Processing Record 46 of Set 12 | thabazimbi
# Processing Record 47 of Set 12 | badin
# Processing Record 48 of Set 12 | kyra
# Processing Record 49 of Set 12 | andenes
# Processing Record 50 of Set 12 | villa bruzual
# Processing Record 1 of Set 13 | ancud
# Processing Record 2 of Set 13 | morehead
# Processing Record 3 of Set 13 | acapulco
# Processing Record 4 of Set 13 | le pradet
# Processing Record 5 of Set 13 | sarangani
# Processing Record 6 of Set 13 | alindao
# Processing Record 7 of Set 13 | lesnyye polyany
# Processing Record 8 of Set 13 | porto velho
# Processing Record 9 of Set 13 | weihai
# Processing Record 10 of Set 13 | sovetskiy
# Processing Record 11 of Set 13 | hagere hiywet
# Processing Record 12 of Set 13 | shebunino
# Processing Record 13 of Set 13 | pacific grove
# Processing Record 14 of Set 13 | maketu
# Processing Record 15 of Set 13 | yulara
# Processing Record 16 of Set 13 | togur
# Processing Record 17 of Set 13 | gat
# Processing Record 18 of Set 13 | ilhabela
# Processing Record 19 of Set 13 | gomel
# Processing Record 20 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 21 of Set 13 | varna
# Processing Record 22 of Set 13 | cedar city
# Processing Record 23 of Set 13 | chifeng
# Processing Record 24 of Set 13 | belaya gora
# Processing Record 25 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 26 of Set 13 | gloucester
# Processing Record 27 of Set 13 | iztapa
# Processing Record 28 of Set 13 | kirkwood
# Processing Record 29 of Set 13 | skiros
# City not found. Skipping...
# Processing Record 30 of Set 13 | kalinovo
# Processing Record 31 of Set 13 | fort-shevchenko
# Processing Record 32 of Set 13 | caronport
# Processing Record 33 of Set 13 | porto torres
# Processing Record 34 of Set 13 | cap malheureux
# Processing Record 35 of Set 13 | auki
# Processing Record 36 of Set 13 | himora
# City not found. Skipping...
# Processing Record 37 of Set 13 | walvis bay
# Processing Record 38 of Set 13 | kajaani
# Processing Record 39 of Set 13 | mahaicony
# City not found. Skipping...
# Processing Record 40 of Set 13 | nizhneangarsk
# Processing Record 41 of Set 13 | pushkinskiye gory
# Processing Record 42 of Set 13 | thilogne
# City not found. Skipping...
# Processing Record 43 of Set 13 | mukhen
# Processing Record 44 of Set 13 | ahuimanu
# Processing Record 45 of Set 13 | kilembe
# Processing Record 46 of Set 13 | manono
# Processing Record 47 of Set 13 | ojinaga
# Processing Record 48 of Set 13 | woodward
# Processing Record 49 of Set 13 | vila
# Processing Record 50 of Set 13 | mezen
# Processing Record 1 of Set 14 | puerto baquerizo moreno
# Processing Record 2 of Set 14 | axim
# Processing Record 3 of Set 14 | lumphat
# Processing Record 4 of Set 14 | kavieng
# Processing Record 5 of Set 14 | berja
# Processing Record 6 of Set 14 | russell
# Processing Record 7 of Set 14 | mountain home
# Processing Record 8 of Set 14 | nicoya
# Processing Record 9 of Set 14 | nombre de dios
# Processing Record 10 of Set 14 | aykhal
# Processing Record 11 of Set 14 | coahuayana
# Processing Record 12 of Set 14 | zambezi
# Processing Record 13 of Set 14 | urengoy
# Processing Record 14 of Set 14 | muhos
# Processing Record 15 of Set 14 | weligama
# Processing Record 16 of Set 14 | ulaangom
# Processing Record 17 of Set 14 | maputo
# Processing Record 18 of Set 14 | simao
# Processing Record 19 of Set 14 | nizhniy odes
# Processing Record 20 of Set 14 | havoysund
# Processing Record 21 of Set 14 | bone
# Processing Record 22 of Set 14 | magadan
# Processing Record 23 of Set 14 | wucheng
# Processing Record 24 of Set 14 | waipawa
# Processing Record 25 of Set 14 | dudinka
# Processing Record 26 of Set 14 | umarkot
# Processing Record 27 of Set 14 | santa maria
# Processing Record 28 of Set 14 | san felipe
# Processing Record 29 of Set 14 | nefteyugansk
# Processing Record 30 of Set 14 | mabay
# Processing Record 31 of Set 14 | leglise
# Processing Record 32 of Set 14 | dicabisagan
# Processing Record 33 of Set 14 | lavrentiya
# Processing Record 34 of Set 14 | pokrovsk
# Processing Record 35 of Set 14 | neftcala
# Processing Record 36 of Set 14 | ponta delgada
# Processing Record 37 of Set 14 | mancheral
# Processing Record 38 of Set 14 | nichinan
# Processing Record 39 of Set 14 | road town
# Processing Record 40 of Set 14 | kamenka
# Processing Record 41 of Set 14 | brasilia de minas
# Processing Record 42 of Set 14 | jiuquan
# Processing Record 43 of Set 14 | arrifes
# Processing Record 44 of Set 14 | pittsburg
# Processing Record 45 of Set 14 | malko tarnovo
# Processing Record 46 of Set 14 | duz
# City not found. Skipping...
# Processing Record 47 of Set 14 | montrose
# Processing Record 48 of Set 14 | gagino
# Processing Record 49 of Set 14 | turayf
# Processing Record 50 of Set 14 | khor
# Processing Record 1 of Set 15 | cururupu
# Processing Record 2 of Set 15 | jabiru
# City not found. Skipping...
# Processing Record 3 of Set 15 | zhanaozen
# Processing Record 4 of Set 15 | chino valley
# Processing Record 5 of Set 15 | brigantine
# Processing Record 6 of Set 15 | maloshuyka
# City not found. Skipping...
# Processing Record 7 of Set 15 | linchuan
# City not found. Skipping...
# Processing Record 8 of Set 15 | tonj
# Processing Record 9 of Set 15 | chara
# Processing Record 10 of Set 15 | grants pass
# Processing Record 11 of Set 15 | cowra
# Processing Record 12 of Set 15 | ha giang
# Processing Record 13 of Set 15 | ejea de los caballeros
# Processing Record 14 of Set 15 | canutama
# Processing Record 15 of Set 15 | nanlong
# Processing Record 16 of Set 15 | atambua
# Processing Record 17 of Set 15 | khasan
# Processing Record 18 of Set 15 | santa fe
# Processing Record 19 of Set 15 | luena
# Processing Record 20 of Set 15 | nador
# Processing Record 21 of Set 15 | itoman
# Processing Record 22 of Set 15 | filadelfia
# Processing Record 23 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 24 of Set 15 | cheuskiny
# City not found. Skipping...
# Processing Record 25 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 15 | novoanninskiy
# Processing Record 27 of Set 15 | naze
# Processing Record 28 of Set 15 | leshukonskoye
# Processing Record 29 of Set 15 | garachine
# Processing Record 30 of Set 15 | christchurch
# Processing Record 31 of Set 15 | tual
# Processing Record 32 of Set 15 | aljezur
# Processing Record 33 of Set 15 | la sarre
# Processing Record 34 of Set 15 | verin
# Processing Record 35 of Set 15 | brookhaven
# Processing Record 36 of Set 15 | batemans bay
# Processing Record 37 of Set 15 | urumqi
# Processing Record 38 of Set 15 | nam tha
# City not found. Skipping...
# Processing Record 39 of Set 15 | egvekinot
# Processing Record 40 of Set 15 | susanville
# Processing Record 41 of Set 15 | riyadh
# Processing Record 42 of Set 15 | pemba
# Processing Record 43 of Set 15 | bagdarin
# Processing Record 44 of Set 15 | terpinnya
# Processing Record 45 of Set 15 | karaul
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Verkhoturye',
#   'Country': 'RU',
#   'Lat': 58.8627,
#   'Lng': 60.8054,
#   'Max Temp': 2.03,
#   'Humidity': 90,
#   'Cloudiness': 88,
#   'Wind Speed': 11.03,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 64.81,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Putina',
#   'Country': 'PE',
#   'Lat': -15.4667,
#   'Lng': -69.4333,
#   'Max Temp': 49.35,
#   'Humidity': 74,
#   'Cloudiness': 71,
#   'Wind Speed': 8.32,
#   'Current Description': 'light rain'},
#  {'City': 'Taoudenni',
#   'Country': 'ML',
#   'Lat': 22.6783,
#   'Lng': -3.9836,
#   'Max Temp': 68.38,
#   'Humidity': 25,
#   'Cloudiness': 89,
#   'Wind Speed': 9.15,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 61.29,
#   'Humidity': 90,
#   'Cloudiness': 78,
#   'Wind Speed': 12.3,
#   'Current Description': 'broken clouds'},
#  {'City': 'Khatanga',
#   'Country': 'RU',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': -28.82,
#   'Humidity': 100,
#   'Cloudiness': 13,
#   'Wind Speed': 5.53,
#   'Current Description': 'few clouds'},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 73.04,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 16.44,
#   'Current Description': 'clear sky'},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 65.48,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 3.33,
#   'Current Description': 'clear sky'},
#  {'City': 'Broome',
#   'Country': 'US',
#   'Lat': 42.2506,
#   'Lng': -75.833,
#   'Max Temp': 36.68,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 80.22,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 12.06,
#   'Current Description': 'clear sky'},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 55.63,
#   'Humidity': 70,
#   'Cloudiness': 91,
#   'Wind Speed': 7.63,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Upernavik',
#   'Country': 'GL',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 5.83,
#   'Humidity': 93,
#   'Cloudiness': 97,
#   'Wind Speed': 11.54,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Elko',
#   'Country': 'US',
#   'Lat': 41.0002,
#   'Lng': -115.5012,
#   'Max Temp': 34.74,
#   'Humidity': 91,
#   'Cloudiness': 98,
#   'Wind Speed': 11.01,
#   'Current Description': 'snow'},
#  {'City': 'Vyksa',
#   'Country': 'RU',
#   'Lat': 55.3175,
#   'Lng': 42.1744,
#   'Max Temp': 6.08,
#   'Humidity': 88,
#   'Cloudiness': 52,
#   'Wind Speed': 14.38,
#   'Current Description': 'broken clouds'},
#  {'City': 'Rosario Oeste',
#   'Country': 'BR',
#   'Lat': -14.8361,
#   'Lng': -56.4275,
#   'Max Temp': 75.04,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 3.24,
#   'Current Description': 'light rain'},
#  {'City': 'Saint-Philippe',
#   'Country': 'RE',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 78.39,
#   'Humidity': 87,
#   'Cloudiness': 98,
#   'Wind Speed': 1.12,
#   'Current Description': 'light rain'},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 77.67,
#   'Humidity': 68,
#   'Cloudiness': 68,
#   'Wind Speed': 8.77,
#   'Current Description': 'broken clouds'},
#  {'City': 'Norman Wells',
#   'Country': 'CA',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': -7.15,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 6.8,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sao Filipe',
#   'Country': 'CV',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 75.51,
#   'Humidity': 68,
#   'Cloudiness': 82,
#   'Wind Speed': 8.08,
#   'Current Description': 'broken clouds'},
#  {'City': 'Saint George',
#   'Country': 'US',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 57.25,
#   'Humidity': 52,
#   'Cloudiness': 75,
#   'Wind Speed': 1.01,
#   'Current Description': 'broken clouds'},
#  {'City': 'Luangwa',
#   'Country': 'ZM',
#   'Lat': -15.6167,
#   'Lng': 30.4167,
#   'Max Temp': 72.88,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 0.45,
#   'Current Description': 'moderate rain'},
#  {'City': 'Aberdeen',
#   'Country': 'GB',
#   'Lat': 57.1437,
#   'Lng': -2.0981,
#   'Max Temp': 39.69,
#   'Humidity': 69,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Esperance',
#   'Country': 'AU',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 68.4,
#   'Humidity': 66,
#   'Cloudiness': 1,
#   'Wind Speed': 12.86,
#   'Current Description': 'clear sky'},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 78.64,
#   'Humidity': 75,
#   'Cloudiness': 7,
#   'Wind Speed': 11.63,
#   'Current Description': 'clear sky'},
#  {'City': 'Berlevag',
#   'Country': 'NO',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 28.17,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 15.48,
#   'Current Description': 'light snow'},
#  {'City': 'Bathsheba',
#   'Country': 'BB',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp': 78.6,
#   'Humidity': 76,
#   'Cloudiness': 82,
#   'Wind Speed': 15.77,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ponta Do Sol',
#   'Country': 'PT',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 66.83,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 14.72,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tawang',
#   'Country': 'IN',
#   'Lat': 27.5833,
#   'Lng': 91.8667,
#   'Max Temp': 19.69,
#   'Humidity': 82,
#   'Cloudiness': 10,
#   'Wind Speed': 7.29,
#   'Current Description': 'clear sky'},
#  {'City': 'Verkhnevilyuysk',
#   'Country': 'RU',
#   'Lat': 63.4453,
#   'Lng': 120.3167,
#   'Max Temp': -18.2,
#   'Humidity': 99,
#   'Cloudiness': 99,
#   'Wind Speed': 3.94,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yatou',
#   'Country': 'CN',
#   'Lat': 37.15,
#   'Lng': 122.3833,
#   'Max Temp': 20.46,
#   'Humidity': 80,
#   'Cloudiness': 91,
#   'Wind Speed': 19.75,
#   'Current Description': 'light snow'},
#  {'City': 'Georgetown',
#   'Country': 'MY',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 78.89,
#   'Humidity': 92,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Current Description': 'few clouds'},
#  {'City': 'Ashington',
#   'Country': 'GB',
#   'Lat': 50.9331,
#   'Lng': -0.3909,
#   'Max Temp': 50.43,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Twante',
#   'Country': 'MM',
#   'Lat': 16.7167,
#   'Lng': 95.9333,
#   'Max Temp': 64.53,
#   'Humidity': 83,
#   'Cloudiness': 3,
#   'Wind Speed': 4.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Manokwari',
#   'Country': 'ID',
#   'Lat': -0.8667,
#   'Lng': 134.0833,
#   'Max Temp': 81.37,
#   'Humidity': 75,
#   'Cloudiness': 95,
#   'Wind Speed': 4.34,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Caravelas',
#   'Country': 'BR',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 70.23,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 6.04,
#   'Current Description': 'light rain'},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 75.25,
#   'Humidity': 56,
#   'Cloudiness': 79,
#   'Wind Speed': 7.72,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ostrovnoy',
#   'Country': 'RU',
#   'Lat': 68.0531,
#   'Lng': 39.5131,
#   'Max Temp': 14.05,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 17.87,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Avarua',
#   'Country': 'CK',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 82.45,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 18.41,
#   'Current Description': 'light rain'},
#  {'City': 'East London',
#   'Country': 'ZA',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 64.15,
#   'Humidity': 90,
#   'Cloudiness': 72,
#   'Wind Speed': 10.11,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 78.78,
#   'Humidity': 69,
#   'Cloudiness': 29,
#   'Wind Speed': 4,
#   'Current Description': 'light rain'},
#  {'City': 'Berdigestyakh',
#   'Country': 'RU',
#   'Lat': 62.0989,
#   'Lng': 126.6992,
#   'Max Temp': -35.84,
#   'Humidity': 100,
#   'Cloudiness': 98,
#   'Wind Speed': 0.36,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Majene',
#   'Country': 'ID',
#   'Lat': -3.5403,
#   'Lng': 118.9707,
#   'Max Temp': 80.29,
#   'Humidity': 76,
#   'Cloudiness': 96,
#   'Wind Speed': 5.41,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dikson',
#   'Country': 'RU',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': -6.54,
#   'Humidity': 88,
#   'Cloudiness': 48,
#   'Wind Speed': 7.96,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Chokurdakh',
#   'Country': 'RU',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': -37.46,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 6.64,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Albany',
#   'Country': 'US',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 28.51,
#   'Humidity': 85,
#   'Cloudiness': 92,
#   'Wind Speed': 2.08,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Along',
#   'Country': 'IN',
#   'Lat': 28.1667,
#   'Lng': 94.7667,
#   'Max Temp': 46.67,
#   'Humidity': 66,
#   'Cloudiness': 50,
#   'Wind Speed': 1.72,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Provideniya',
#   'Country': 'RU',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 8.37,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 18.57,
#   'Current Description': 'snow'},
#  {'City': 'Dingle',
#   'Country': 'PH',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 75.29,
#   'Humidity': 93,
#   'Cloudiness': 67,
#   'Wind Speed': 6.31,
#   'Current Description': 'broken clouds'},
#  {'City': 'Butaritari',
#   'Country': 'KI',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 81.79,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 9.62,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nabire',
#   'Country': 'ID',
#   'Lat': -3.3667,
#   'Lng': 135.4833,
#   'Max Temp': 83.16,
#   'Humidity': 72,
#   'Cloudiness': 70,
#   'Wind Speed': 0.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ayagoz',
#   'Country': 'KZ',
#   'Lat': 47.9714,
#   'Lng': 80.4392,
#   'Max Temp': 14.85,
#   'Humidity': 89,
#   'Cloudiness': 99,
#   'Wind Speed': 7.87,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sambava',
#   'Country': 'MG',
#   'Lat': -14.2667,
#   'Lng': 50.1667,
#   'Max Temp': 74.43,
#   'Humidity': 91,
#   'Cloudiness': 56,
#   'Wind Speed': 4.85,
#   'Current Description': 'broken clouds'},
#  {'City': 'Arraial Do Cabo',
#   'Country': 'BR',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 73.2,
#   'Humidity': 74,
#   'Cloudiness': 10,
#   'Wind Speed': 11.32,
#   'Current Description': 'clear sky'},
#  {'City': 'Ubinskoye',
#   'Country': 'RU',
#   'Lat': 55.3068,
#   'Lng': 79.6802,
#   'Max Temp': -2.27,
#   'Humidity': 97,
#   'Cloudiness': 65,
#   'Wind Speed': 2.82,
#   'Current Description': 'broken clouds'},
#  {'City': 'Coronel',
#   'Country': 'CL',
#   'Lat': -37.0167,
#   'Lng': -73.1333,
#   'Max Temp': 64.83,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 11.07,
#   'Current Description': 'clear sky'},
#  {'City': 'Matara',
#   'Country': 'LK',
#   'Lat': 5.9485,
#   'Lng': 80.5353,
#   'Max Temp': 72.3,
#   'Humidity': 88,
#   'Cloudiness': 65,
#   'Wind Speed': 7.74,
#   'Current Description': 'broken clouds'},
#  {'City': 'Wuchi',
#   'Country': 'CN',
#   'Lat': 29.3786,
#   'Lng': 103.023,
#   'Max Temp': 35.11,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 2.82,
#   'Current Description': 'light rain'},
#  {'City': 'Portland',
#   'Country': 'US',
#   'Lat': 45.5234,
#   'Lng': -122.6762,
#   'Max Temp': 41.52,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Current Description': 'light rain'},
#  {'City': 'Englewood',
#   'Country': 'US',
#   'Lat': 39.6478,
#   'Lng': -104.9878,
#   'Max Temp': 43.41,
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 1.99,
#   'Current Description': 'broken clouds'},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 79.57,
#   'Humidity': 65,
#   'Cloudiness': 21,
#   'Wind Speed': 6.55,
#   'Current Description': 'few clouds'},
#  {'City': 'Castro',
#   'Country': 'BR',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 56.48,
#   'Humidity': 91,
#   'Cloudiness': 16,
#   'Wind Speed': 7.18,
#   'Current Description': 'few clouds'},
#  {'City': 'Mandera',
#   'Country': 'KE',
#   'Lat': 3.9366,
#   'Lng': 41.867,
#   'Max Temp': 80.67,
#   'Humidity': 68,
#   'Cloudiness': 78,
#   'Wind Speed': 15.57,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 65.8,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 4.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Te Anau',
#   'Country': 'NZ',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 68.18,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 2.84,
#   'Current Description': 'clear sky'},
#  {'City': 'Likasi',
#   'Country': 'CD',
#   'Lat': -10.9814,
#   'Lng': 26.7333,
#   'Max Temp': 61.27,
#   'Humidity': 98,
#   'Cloudiness': 99,
#   'Wind Speed': 4.05,
#   'Current Description': 'light rain'},
#  {'City': 'Fethiye',
#   'Country': 'TR',
#   'Lat': 36.6217,
#   'Lng': 29.1164,
#   'Max Temp': 35.47,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 5.79,
#   'Current Description': 'clear sky'},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 66.9,
#   'Humidity': 85,
#   'Cloudiness': 95,
#   'Wind Speed': 13.62,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Watsa',
#   'Country': 'CD',
#   'Lat': 3.0372,
#   'Lng': 29.5355,
#   'Max Temp': 66.83,
#   'Humidity': 72,
#   'Cloudiness': 84,
#   'Wind Speed': 2.28,
#   'Current Description': 'broken clouds'},
#  {'City': 'Buta',
#   'Country': 'CD',
#   'Lat': 2.7858,
#   'Lng': 24.73,
#   'Max Temp': 72.21,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 2.42,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 3.25,
#   'Humidity': 85,
#   'Cloudiness': 98,
#   'Wind Speed': 6.44,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Aginskoye',
#   'Country': 'RU',
#   'Lat': 51.1,
#   'Lng': 114.53,
#   'Max Temp': -15.59,
#   'Humidity': 85,
#   'Cloudiness': 7,
#   'Wind Speed': 7.85,
#   'Current Description': 'clear sky'},
#  {'City': 'Port-Gentil',
#   'Country': 'GA',
#   'Lat': -0.7193,
#   'Lng': 8.7815,
#   'Max Temp': 79.95,
#   'Humidity': 84,
#   'Cloudiness': 19,
#   'Wind Speed': 15.05,
#   'Current Description': 'few clouds'},
#  {'City': 'Boyuibe',
#   'Country': 'BO',
#   'Lat': -20.4167,
#   'Lng': -63.2833,
#   'Max Temp': 74.1,
#   'Humidity': 69,
#   'Cloudiness': 97,
#   'Wind Speed': 3.31,
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Ignacio',
#   'Country': 'BZ',
#   'Lat': 17.1561,
#   'Lng': -89.0714,
#   'Max Temp': 69.58,
#   'Humidity': 74,
#   'Cloudiness': 19,
#   'Wind Speed': 3.94,
#   'Current Description': 'few clouds'},
#  {'City': 'Lucapa',
#   'Country': 'AO',
#   'Lat': -8.4192,
#   'Lng': 20.7447,
#   'Max Temp': 65.44,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.46,
#   'Current Description': 'light rain'},
#  {'City': 'Chuy',
#   'Country': 'UY',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 67.91,
#   'Humidity': 79,
#   'Cloudiness': 2,
#   'Wind Speed': 13.53,
#   'Current Description': 'clear sky'},
#  {'City': 'Ulladulla',
#   'Country': 'AU',
#   'Lat': -35.35,
#   'Lng': 150.4667,
#   'Max Temp': 86.77,
#   'Humidity': 58,
#   'Cloudiness': 6,
#   'Wind Speed': 6.8,
#   'Current Description': 'clear sky'},
#  {'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 81.63,
#   'Humidity': 75,
#   'Cloudiness': 32,
#   'Wind Speed': 8.43,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bengkulu',
#   'Country': 'ID',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 76.28,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 4.56,
#   'Current Description': 'broken clouds'},
#  {'City': 'Namibe',
#   'Country': 'AO',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 67.32,
#   'Humidity': 75,
#   'Cloudiness': 27,
#   'Wind Speed': 7.27,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Verkh-Usugli',
#   'Country': 'RU',
#   'Lat': 52.7,
#   'Lng': 115.1667,
#   'Max Temp': -17.12,
#   'Humidity': 84,
#   'Cloudiness': 37,
#   'Wind Speed': 2.98,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 69.12,
#   'Humidity': 46,
#   'Cloudiness': 20,
#   'Wind Speed': 5.01,
#   'Current Description': 'few clouds'},
#  {'City': 'Dakar',
#   'Country': 'SN',
#   'Lat': 14.6937,
#   'Lng': -17.4441,
#   'Max Temp': 77.88,
#   'Humidity': 66,
#   'Cloudiness': 99,
#   'Wind Speed': 13.6,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bilma',
#   'Country': 'NE',
#   'Lat': 18.6853,
#   'Lng': 12.9164,
#   'Max Temp': 61.34,
#   'Humidity': 22,
#   'Cloudiness': 5,
#   'Wind Speed': 8.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Grand Gaube',
#   'Country': 'MU',
#   'Lat': -20.0064,
#   'Lng': 57.6608,
#   'Max Temp': 76.37,
#   'Humidity': 85,
#   'Cloudiness': 97,
#   'Wind Speed': 3.74,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Puro',
#   'Country': 'PH',
#   'Lat': 12.4841,
#   'Lng': 123.3827,
#   'Max Temp': 79.77,
#   'Humidity': 81,
#   'Cloudiness': 61,
#   'Wind Speed': 10.56,
#   'Current Description': 'broken clouds'},
#  {'City': 'Nouakchott',
#   'Country': 'MR',
#   'Lat': 18.0858,
#   'Lng': -15.9785,
#   'Max Temp': 71.53,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 11.25,
#   'Current Description': 'clear sky'},
#  {'City': 'Vestmannaeyjar',
#   'Country': 'IS',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp': 38.98,
#   'Humidity': 78,
#   'Cloudiness': 85,
#   'Wind Speed': 21.36,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ribeira Grande',
#   'Country': 'PT',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 63.81,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 15.19,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Paita',
#   'Country': 'PE',
#   'Lat': -5.0892,
#   'Lng': -81.1144,
#   'Max Temp': 69.89,
#   'Humidity': 82,
#   'Cloudiness': 10,
#   'Wind Speed': 16.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Santa Isabel Do Rio Negro',
#   'Country': 'BR',
#   'Lat': -0.4139,
#   'Lng': -65.0192,
#   'Max Temp': 78.42,
#   'Humidity': 79,
#   'Cloudiness': 64,
#   'Wind Speed': 2.44,
#   'Current Description': 'broken clouds'},
#  {'City': 'Champerico',
#   'Country': 'GT',
#   'Lat': 14.3,
#   'Lng': -91.9167,
#   'Max Temp': 83.35,
#   'Humidity': 66,
#   'Cloudiness': 5,
#   'Wind Speed': 5.7,
#   'Current Description': 'clear sky'},
#  {'City': 'Tayu',
#   'Country': 'ID',
#   'Lat': -6.5397,
#   'Lng': 111.0518,
#   'Max Temp': 80.89,
#   'Humidity': 77,
#   'Cloudiness': 99,
#   'Wind Speed': 2.48,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Samarai',
#   'Country': 'PG',
#   'Lat': -10.6167,
#   'Lng': 150.6667,
#   'Max Temp': 84.45,
#   'Humidity': 70,
#   'Cloudiness': 45,
#   'Wind Speed': 7.94,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sitka',
#   'Country': 'US',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 28.29,
#   'Humidity': 31,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Current Description': 'few clouds'},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 51.39,
#   'Humidity': 61,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ahipara',
#   'Country': 'NZ',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 74.61,
#   'Humidity': 52,
#   'Cloudiness': 11,
#   'Wind Speed': 6.6,
#   'Current Description': 'few clouds'},
#  {'City': 'Kattivakkam',
#   'Country': 'IN',
#   'Lat': 13.2167,
#   'Lng': 80.3167,
#   'Max Temp': 73.08,
#   'Humidity': 87,
#   'Cloudiness': 27,
#   'Wind Speed': 4.05,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Xining',
#   'Country': 'CN',
#   'Lat': 36.6167,
#   'Lng': 101.7667,
#   'Max Temp': 15.42,
#   'Humidity': 77,
#   'Cloudiness': 36,
#   'Wind Speed': 1.52,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Igrim',
#   'Country': 'RU',
#   'Lat': 63.1906,
#   'Lng': 64.4162,
#   'Max Temp': 3.38,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 9.46,
#   'Current Description': 'light snow'},
#  {'City': 'Tias',
#   'Country': 'ES',
#   'Lat': 28.9611,
#   'Lng': -13.645,
#   'Max Temp': 60.55,
#   'Humidity': 82,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Current Description': 'few clouds'},
#  {'City': 'Flinders',
#   'Country': 'AU',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 84.18,
#   'Humidity': 69,
#   'Cloudiness': 26,
#   'Wind Speed': 9.55,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Wajima',
#   'Country': 'JP',
#   'Lat': 37.4,
#   'Lng': 136.9,
#   'Max Temp': 36.48,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 23.8,
#   'Current Description': 'light rain'},
#  {'City': 'Ledyard',
#   'Country': 'US',
#   'Lat': 41.4398,
#   'Lng': -72.0142,
#   'Max Temp': 31.17,
#   'Humidity': 84,
#   'Cloudiness': 90,
#   'Wind Speed': 1.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nuqui',
#   'Country': 'CO',
#   'Lat': 5.7125,
#   'Lng': -77.2708,
#   'Max Temp': 78.04,
#   'Humidity': 88,
#   'Cloudiness': 74,
#   'Wind Speed': 1.28,
#   'Current Description': 'light rain'},
#  {'City': 'Yellowknife',
#   'Country': 'CA',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': -7.6,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 7.74,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mount Gambier',
#   'Country': 'AU',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 62.51,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 13.8,
#   'Current Description': 'overcast clouds'},
#  {'City': 'The Valley',
#   'Country': 'AI',
#   'Lat': 18.217,
#   'Lng': -63.0578,
#   'Max Temp': 78.1,
#   'Humidity': 69,
#   'Cloudiness': 8,
#   'Wind Speed': 8.57,
#   'Current Description': 'clear sky'},
#  {'City': 'Taicheng',
#   'Country': 'CN',
#   'Lat': 38.731,
#   'Lng': 113.228,
#   'Max Temp': 3.52,
#   'Humidity': 64,
#   'Cloudiness': 9,
#   'Wind Speed': 3.31,
#   'Current Description': 'clear sky'},
#  {'City': 'Celestun',
#   'Country': 'MX',
#   'Lat': 20.8667,
#   'Lng': -90.4,
#   'Max Temp': 74.41,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 15.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Waw',
#   'Country': 'SS',
#   'Lat': 7.7029,
#   'Lng': 27.9953,
#   'Max Temp': 73.35,
#   'Humidity': 27,
#   'Cloudiness': 70,
#   'Wind Speed': 4.92,
#   'Current Description': 'broken clouds'},
#  {'City': 'Nome',
#   'Country': 'US',
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': 17.11,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 24.16,
#   'Current Description': 'snow'},
#  {'City': 'Iseyin',
#   'Country': 'NG',
#   'Lat': 7.9667,
#   'Lng': 3.6,
#   'Max Temp': 75.69,
#   'Humidity': 58,
#   'Cloudiness': 47,
#   'Wind Speed': 3.69,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Palu',
#   'Country': 'ID',
#   'Lat': -0.8917,
#   'Lng': 119.8707,
#   'Max Temp': 79.66,
#   'Humidity': 76,
#   'Cloudiness': 81,
#   'Wind Speed': 1.74,
#   'Current Description': 'broken clouds'},
#  {'City': 'Port Hardy',
#   'Country': 'CA',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 31.87,
#   'Humidity': 61,
#   'Cloudiness': 54,
#   'Wind Speed': 5.53,
#   'Current Description': 'broken clouds'},
#  {'City': 'Azul',
#   'Country': 'AR',
#   'Lat': -36.777,
#   'Lng': -59.8585,
#   'Max Temp': 72.34,
#   'Humidity': 73,
#   'Cloudiness': 73,
#   'Wind Speed': 3.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Wattegama',
#   'Country': 'LK',
#   'Lat': 6.7989,
#   'Lng': 81.4808,
#   'Max Temp': 66.09,
#   'Humidity': 90,
#   'Cloudiness': 5,
#   'Wind Speed': 3.94,
#   'Current Description': 'clear sky'},
#  {'City': 'Pevek',
#   'Country': 'RU',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': -23.69,
#   'Humidity': 100,
#   'Cloudiness': 95,
#   'Wind Speed': 1.34,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mar Del Plata',
#   'Country': 'AR',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 69.82,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mahebourg',
#   'Country': 'MU',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 76.24,
#   'Humidity': 78,
#   'Cloudiness': 98,
#   'Wind Speed': 1.23,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bac Lieu',
#   'Country': 'VN',
#   'Lat': 9.285,
#   'Lng': 105.7244,
#   'Max Temp': 76.95,
#   'Humidity': 84,
#   'Cloudiness': 73,
#   'Wind Speed': 13.18,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kodiak',
#   'Country': 'US',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 47.71,
#   'Humidity': 34,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Los Llanos De Aridane',
#   'Country': 'ES',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 60.55,
#   'Humidity': 91,
#   'Cloudiness': 75,
#   'Wind Speed': 3,
#   'Current Description': 'broken clouds'},
#  {'City': 'Salinas',
#   'Country': 'US',
#   'Lat': 36.6777,
#   'Lng': -121.6555,
#   'Max Temp': 55.71,
#   'Humidity': 63,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 23.16,
#   'Humidity': 53,
#   'Cloudiness': 4,
#   'Wind Speed': 5.19,
#   'Current Description': 'clear sky'},
#  {'City': 'Katsuura',
#   'Country': 'JP',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 51.82,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 6.49,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gazanjyk',
#   'Country': 'TM',
#   'Lat': 39.2446,
#   'Lng': 55.5154,
#   'Max Temp': 33.22,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 12.33,
#   'Current Description': 'snow'},
#  {'City': 'Tuktoyaktuk',
#   'Country': 'CA',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': -12.89,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 14.63,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Prado',
#   'Country': 'BR',
#   'Lat': -17.3411,
#   'Lng': -39.2208,
#   'Max Temp': 69.13,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 7.49,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Rapid Valley',
#   'Country': 'US',
#   'Lat': 44.0625,
#   'Lng': -103.1463,
#   'Max Temp': 37.04,
#   'Humidity': 60,
#   'Cloudiness': 1,
#   'Wind Speed': 3,
#   'Current Description': 'clear sky'},
#  {'City': 'Sao Lourenco Do Sul',
#   'Country': 'BR',
#   'Lat': -31.3653,
#   'Lng': -51.9783,
#   'Max Temp': 69.89,
#   'Humidity': 78,
#   'Cloudiness': 6,
#   'Wind Speed': 11.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Alugan',
#   'Country': 'PH',
#   'Lat': 12.2188,
#   'Lng': 125.4808,
#   'Max Temp': 81.37,
#   'Humidity': 78,
#   'Cloudiness': 82,
#   'Wind Speed': 10.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ust-Kut',
#   'Country': 'RU',
#   'Lat': 56.7938,
#   'Lng': 105.7672,
#   'Max Temp': -22.23,
#   'Humidity': 95,
#   'Cloudiness': 53,
#   'Wind Speed': 2.55,
#   'Current Description': 'broken clouds'},
#  {'City': 'Torbay',
#   'Country': 'CA',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 25.57,
#   'Humidity': 82,
#   'Cloudiness': 95,
#   'Wind Speed': 7,
#   'Current Description': 'light snow'},
#  {'City': 'Souillac',
#   'Country': 'MU',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 76.35,
#   'Humidity': 77,
#   'Cloudiness': 99,
#   'Wind Speed': 2.95,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kothi',
#   'Country': 'IN',
#   'Lat': 24.75,
#   'Lng': 80.7833,
#   'Max Temp': 55.15,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 2.48,
#   'Current Description': 'clear sky'},
#  {'City': 'College',
#   'Country': 'US',
#   'Lat': 64.8569,
#   'Lng': -147.8028,
#   'Max Temp': -3.33,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 3.02,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Teahupoo',
#   'Country': 'PF',
#   'Lat': -17.8333,
#   'Lng': -149.2667,
#   'Max Temp': 82.36,
#   'Humidity': 73,
#   'Cloudiness': 57,
#   'Wind Speed': 10.31,
#   'Current Description': 'broken clouds'},
#  {'City': 'Henderson',
#   'Country': 'US',
#   'Lat': 36.0397,
#   'Lng': -114.9819,
#   'Max Temp': 62.04,
#   'Humidity': 45,
#   'Cloudiness': 1,
#   'Wind Speed': 20.71,
#   'Current Description': 'clear sky'},
#  {'City': 'Nanortalik',
#   'Country': 'GL',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 31.98,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 17.65,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tarko-Sale',
#   'Country': 'RU',
#   'Lat': 64.9225,
#   'Lng': 77.785,
#   'Max Temp': 9.27,
#   'Humidity': 88,
#   'Cloudiness': 99,
#   'Wind Speed': 22.35,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Wembley',
#   'Country': 'AU',
#   'Lat': -31.9333,
#   'Lng': 115.8,
#   'Max Temp': 81.09,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 19.57,
#   'Current Description': 'clear sky'},
#  {'City': 'Luderitz',
#   'Country': 'NA',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 61.77,
#   'Humidity': 95,
#   'Cloudiness': 11,
#   'Wind Speed': 7.63,
#   'Current Description': 'few clouds'},
#  {'City': 'Ixtapa',
#   'Country': 'MX',
#   'Lat': 20.7,
#   'Lng': -105.2,
#   'Max Temp': 76.23,
#   'Humidity': 87,
#   'Cloudiness': 1,
#   'Wind Speed': 4,
#   'Current Description': 'clear sky'},
#  {'City': 'Talnakh',
#   'Country': 'RU',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': 16.21,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 7.78,
#   'Current Description': 'light snow'},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 59.11,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 27.63,
#   'Current Description': 'light rain'},
#  {'City': 'Thompson',
#   'Country': 'CA',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': -0.24,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Current Description': 'light snow'},
#  {'City': 'Sao Joao Da Barra',
#   'Country': 'BR',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 70.81,
#   'Humidity': 85,
#   'Cloudiness': 99,
#   'Wind Speed': 11.41,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Karasburg',
#   'Country': 'NA',
#   'Lat': -28.0167,
#   'Lng': 18.75,
#   'Max Temp': 67.19,
#   'Humidity': 44,
#   'Cloudiness': 4,
#   'Wind Speed': 14.09,
#   'Current Description': 'clear sky'},
#  {'City': 'Foca',
#   'Country': 'TR',
#   'Lat': 38.6703,
#   'Lng': 26.7566,
#   'Max Temp': 42.64,
#   'Humidity': 66,
#   'Cloudiness': 8,
#   'Wind Speed': 9.62,
#   'Current Description': 'clear sky'},
#  {'City': 'Mayor Pablo Lagerenza',
#   'Country': 'PY',
#   'Lat': -19.9309,
#   'Lng': -60.7718,
#   'Max Temp': 79.47,
#   'Humidity': 48,
#   'Cloudiness': 31,
#   'Wind Speed': 0.51,
#   'Current Description': 'scattered clouds'},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 69.75,
#   'Humidity': 46,
#   'Cloudiness': 47,
#   'Wind Speed': 4,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Port Lincoln',
#   'Country': 'AU',
#   'Lat': -34.7333,
#   'Lng': 135.8667,
#   'Max Temp': 64.18,
#   'Humidity': 76,
#   'Cloudiness': 99,
#   'Wind Speed': 12.88,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Carutapera',
#   'Country': 'BR',
#   'Lat': -1.195,
#   'Lng': -46.02,
#   'Max Temp': 79.65,
#   'Humidity': 81,
#   'Cloudiness': 63,
#   'Wind Speed': 7,
#   'Current Description': 'broken clouds'},
#  {'City': 'Severnoye',
#   'Country': 'RU',
#   'Lat': 56.3491,
#   'Lng': 78.3619,
#   'Max Temp': -4.45,
#   'Humidity': 96,
#   'Cloudiness': 43,
#   'Wind Speed': 5.26,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Esmeraldas',
#   'Country': 'BR',
#   'Lat': -19.7625,
#   'Lng': -44.3139,
#   'Max Temp': 68.86,
#   'Humidity': 92,
#   'Cloudiness': 28,
#   'Wind Speed': 5.79,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kiri Buru',
#   'Country': 'IN',
#   'Lat': 22.0833,
#   'Lng': 85.35,
#   'Max Temp': 55.69,
#   'Humidity': 59,
#   'Cloudiness': 3,
#   'Wind Speed': 1.83,
#   'Current Description': 'clear sky'},
#  {'City': 'Devaprayag',
#   'Country': 'IN',
#   'Lat': 30.15,
#   'Lng': 78.6167,
#   'Max Temp': 47.57,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 4.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Pochutla',
#   'Country': 'MX',
#   'Lat': 15.7432,
#   'Lng': -96.4661,
#   'Max Temp': 80.42,
#   'Humidity': 73,
#   'Cloudiness': 8,
#   'Wind Speed': 3.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Lebu',
#   'Country': 'CL',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 57.69,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 21.56,
#   'Current Description': 'clear sky'},
#  {'City': 'San Rafael Del Sur',
#   'Country': 'NI',
#   'Lat': 11.8485,
#   'Lng': -86.4384,
#   'Max Temp': 81.01,
#   'Humidity': 54,
#   'Cloudiness': 39,
#   'Wind Speed': 14.09,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Santa Cruz De Tenerife',
#   'Country': 'ES',
#   'Lat': 28.4682,
#   'Lng': -16.2546,
#   'Max Temp': 65.71,
#   'Humidity': 93,
#   'Cloudiness': 20,
#   'Wind Speed': 1.01,
#   'Current Description': 'few clouds'},
#  {'City': 'Meulaboh',
#   'Country': 'ID',
#   'Lat': 4.1363,
#   'Lng': 96.1285,
#   'Max Temp': 74.37,
#   'Humidity': 83,
#   'Cloudiness': 30,
#   'Wind Speed': 3.06,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Moroni',
#   'Country': 'KM',
#   'Lat': -11.7022,
#   'Lng': 43.2551,
#   'Max Temp': 79.05,
#   'Humidity': 72,
#   'Cloudiness': 50,
#   'Wind Speed': 5.55,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Severo-Kurilsk',
#   'Country': 'RU',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 28.04,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 9.04,
#   'Current Description': 'light snow'},
#  {'City': 'Bethel',
#   'Country': 'US',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 33.04,
#   'Humidity': 86,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 63.55,
#   'Humidity': 88,
#   'Cloudiness': 73,
#   'Wind Speed': 11.07,
#   'Current Description': 'broken clouds'},
#  {'City': 'Iaciara',
#   'Country': 'BR',
#   'Lat': -14.0958,
#   'Lng': -46.6317,
#   'Max Temp': 67.62,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.16,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kruisfontein',
#   'Country': 'ZA',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 56.88,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 4.72,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yantal',
#   'Country': 'RU',
#   'Lat': 56.8471,
#   'Lng': 105.2542,
#   'Max Temp': -16.1,
#   'Humidity': 90,
#   'Cloudiness': 54,
#   'Wind Speed': 3.76,
#   'Current Description': 'broken clouds'},
#  {'City': 'Rio Grande',
#   'Country': 'BR',
#   'Lat': -32.035,
#   'Lng': -52.0986,
#   'Max Temp': 69.94,
#   'Humidity': 78,
#   'Cloudiness': 18,
#   'Wind Speed': 14.32,
#   'Current Description': 'few clouds'},
#  {'City': 'Kalga',
#   'Country': 'RU',
#   'Lat': 50.9251,
#   'Lng': 118.898,
#   'Max Temp': -21.48,
#   'Humidity': 86,
#   'Cloudiness': 53,
#   'Wind Speed': 4.07,
#   'Current Description': 'broken clouds'},
#  {'City': 'Vao',
#   'Country': 'NC',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 77.81,
#   'Humidity': 80,
#   'Cloudiness': 20,
#   'Wind Speed': 12.44,
#   'Current Description': 'few clouds'},
#  {'City': 'Salalah',
#   'Country': 'OM',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 69.89,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Current Description': 'few clouds'},
#  {'City': 'Saskylakh',
#   'Country': 'RU',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': -40.68,
#   'Humidity': 100,
#   'Cloudiness': 50,
#   'Wind Speed': 1.9,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Esna',
#   'Country': 'EG',
#   'Lat': 25.2934,
#   'Lng': 32.554,
#   'Max Temp': 53.67,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 13.47,
#   'Current Description': 'clear sky'},
#  {'City': 'Vostok',
#   'Country': 'RU',
#   'Lat': 46.4856,
#   'Lng': 135.8833,
#   'Max Temp': -27.83,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 1.95,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Laguna',
#   'Country': 'US',
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 56.05,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 5.01,
#   'Current Description': 'broken clouds'},
#  {'City': 'Yar-Sale',
#   'Country': 'RU',
#   'Lat': 66.8333,
#   'Lng': 70.8333,
#   'Max Temp': 9.73,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 16.87,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Agirish',
#   'Country': 'RU',
#   'Lat': 61.9247,
#   'Lng': 63.0231,
#   'Max Temp': 1.45,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 8.12,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hami',
#   'Country': 'CN',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 25.32,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 1.68,
#   'Current Description': 'clear sky'},
#  {'City': 'Roros',
#   'Country': 'NO',
#   'Lat': 62.5747,
#   'Lng': 11.3842,
#   'Max Temp': 8.44,
#   'Humidity': 92,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Current Description': 'light snow'},
#  {'City': 'Harper',
#   'Country': 'LR',
#   'Lat': 4.375,
#   'Lng': -7.7169,
#   'Max Temp': 79.66,
#   'Humidity': 81,
#   'Cloudiness': 71,
#   'Wind Speed': 6.85,
#   'Current Description': 'broken clouds'},
#  {'City': 'Puerto Escondido',
#   'Country': 'MX',
#   'Lat': 15.85,
#   'Lng': -97.0667,
#   'Max Temp': 81.43,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Current Description': 'few clouds'},
#  {'City': 'Henties Bay',
#   'Country': 'NA',
#   'Lat': -22.116,
#   'Lng': 14.2845,
#   'Max Temp': 61.43,
#   'Humidity': 94,
#   'Cloudiness': 1,
#   'Wind Speed': 1.03,
#   'Current Description': 'clear sky'},
#  {'City': 'Chernyy Yar',
#   'Country': 'RU',
#   'Lat': 48.0624,
#   'Lng': 46.1091,
#   'Max Temp': 13.1,
#   'Humidity': 76,
#   'Cloudiness': 14,
#   'Wind Speed': 11.81,
#   'Current Description': 'few clouds'},
#  {'City': 'Fortuna',
#   'Country': 'US',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 48.54,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Shanghai',
#   'Country': 'CN',
#   'Lat': 31.2222,
#   'Lng': 121.4581,
#   'Max Temp': 40.93,
#   'Humidity': 58,
#   'Cloudiness': 75,
#   'Wind Speed': 3,
#   'Current Description': 'broken clouds'},
#  {'City': 'Huarmey',
#   'Country': 'PE',
#   'Lat': -10.0681,
#   'Lng': -78.1522,
#   'Max Temp': 69.76,
#   'Humidity': 83,
#   'Cloudiness': 30,
#   'Wind Speed': 9.62,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Araouane',
#   'Country': 'ML',
#   'Lat': 18.9048,
#   'Lng': -3.5265,
#   'Max Temp': 70.14,
#   'Humidity': 20,
#   'Cloudiness': 100,
#   'Wind Speed': 9.51,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Maceio',
#   'Country': 'BR',
#   'Lat': -9.6658,
#   'Lng': -35.7353,
#   'Max Temp': 80.47,
#   'Humidity': 79,
#   'Cloudiness': 91,
#   'Wind Speed': 13.09,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ust-Koksa',
#   'Country': 'RU',
#   'Lat': 50.2696,
#   'Lng': 85.6108,
#   'Max Temp': 8.42,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 1.1,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bihoro',
#   'Country': 'JP',
#   'Lat': 43.8228,
#   'Lng': 144.1044,
#   'Max Temp': 17.38,
#   'Humidity': 76,
#   'Cloudiness': 17,
#   'Wind Speed': 2.15,
#   'Current Description': 'few clouds'},
#  {'City': 'Itarema',
#   'Country': 'BR',
#   'Lat': -2.9248,
#   'Lng': -39.9167,
#   'Max Temp': 80.35,
#   'Humidity': 80,
#   'Cloudiness': 81,
#   'Wind Speed': 11.65,
#   'Current Description': 'broken clouds'},
#  {'City': 'Chernyshevskiy',
#   'Country': 'RU',
#   'Lat': 63.0128,
#   'Lng': 112.4714,
#   'Max Temp': -18.89,
#   'Humidity': 96,
#   'Cloudiness': 79,
#   'Wind Speed': 2.53,
#   'Current Description': 'broken clouds'},
#  {'City': 'Havre-Saint-Pierre',
#   'Country': 'CA',
#   'Lat': 50.2334,
#   'Lng': -63.5986,
#   'Max Temp': 22.73,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 26.84,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Semnan',
#   'Country': 'IR',
#   'Lat': 35.5729,
#   'Lng': 53.3971,
#   'Max Temp': 36.59,
#   'Humidity': 60,
#   'Cloudiness': 1,
#   'Wind Speed': 2.39,
#   'Current Description': 'clear sky'},
#  {'City': 'Lago Da Pedra',
#   'Country': 'BR',
#   'Lat': -4.3333,
#   'Lng': -45.1667,
#   'Max Temp': 75.88,
#   'Humidity': 89,
#   'Cloudiness': 58,
#   'Wind Speed': 3,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tateyama',
#   'Country': 'JP',
#   'Lat': 34.9833,
#   'Lng': 139.8667,
#   'Max Temp': 51.73,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Current Description': 'mist'},
#  {'City': 'Nsanje',
#   'Country': 'MW',
#   'Lat': -16.92,
#   'Lng': 35.262,
#   'Max Temp': 76.1,
#   'Humidity': 89,
#   'Cloudiness': 98,
#   'Wind Speed': 1.74,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lodwar',
#   'Country': 'KE',
#   'Lat': 3.1191,
#   'Lng': 35.5973,
#   'Max Temp': 80.98,
#   'Humidity': 61,
#   'Cloudiness': 89,
#   'Wind Speed': 11.14,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pisco',
#   'Country': 'PE',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 69.85,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Current Description': 'clear sky'},
#  {'City': 'Hampton',
#   'Country': 'US',
#   'Lat': 37.0299,
#   'Lng': -76.3452,
#   'Max Temp': 55.42,
#   'Humidity': 56,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Komsomolskiy',
#   'Country': 'UZ',
#   'Lat': 40.4272,
#   'Lng': 71.7189,
#   'Max Temp': 33.22,
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Current Description': 'broken clouds'},
#  {'City': 'Vila Velha',
#   'Country': 'BR',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 73.35,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Current Description': 'light rain'},
#  {'City': 'Hovd',
#   'Country': 'MN',
#   'Lat': 48.0056,
#   'Lng': 91.6419,
#   'Max Temp': -0.11,
#   'Humidity': 71,
#   'Cloudiness': 13,
#   'Wind Speed': 3.69,
#   'Current Description': 'few clouds'},
#  {'City': 'Juquia',
#   'Country': 'BR',
#   'Lat': -24.3208,
#   'Lng': -47.6347,
#   'Max Temp': 64.17,
#   'Humidity': 91,
#   'Cloudiness': 40,
#   'Wind Speed': 1.81,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Gainesville',
#   'Country': 'US',
#   'Lat': 29.6516,
#   'Lng': -82.3248,
#   'Max Temp': 60.94,
#   'Humidity': 77,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Pundaguitan',
#   'Country': 'PH',
#   'Lat': 6.3711,
#   'Lng': 126.1689,
#   'Max Temp': 80.8,
#   'Humidity': 77,
#   'Cloudiness': 79,
#   'Wind Speed': 10.04,
#   'Current Description': 'broken clouds'},
#  {'City': 'Flin Flon',
#   'Country': 'CA',
#   'Lat': 54.7682,
#   'Lng': -101.865,
#   'Max Temp': -4.65,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 10.51,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Baganga',
#   'Country': 'PH',
#   'Lat': 7.5739,
#   'Lng': 126.56,
#   'Max Temp': 80.02,
#   'Humidity': 82,
#   'Cloudiness': 97,
#   'Wind Speed': 5.7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Leningradskiy',
#   'Country': 'RU',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': -21.71,
#   'Humidity': 99,
#   'Cloudiness': 93,
#   'Wind Speed': 4.23,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Surami',
#   'Country': 'GE',
#   'Lat': 42.0243,
#   'Lng': 43.5556,
#   'Max Temp': 13.69,
#   'Humidity': 74,
#   'Cloudiness': 87,
#   'Wind Speed': 4.18,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nikolskoye',
#   'Country': 'RU',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 8.49,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 2.71,
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Cristobal',
#   'Country': 'VE',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 68.22,
#   'Humidity': 93,
#   'Cloudiness': 93,
#   'Wind Speed': 1.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hambantota',
#   'Country': 'LK',
#   'Lat': 6.1241,
#   'Lng': 81.1185,
#   'Max Temp': 71.51,
#   'Humidity': 82,
#   'Cloudiness': 8,
#   'Wind Speed': 13.42,
#   'Current Description': 'clear sky'},
#  {'City': 'Betioky',
#   'Country': 'MG',
#   'Lat': -23.7167,
#   'Lng': 44.3833,
#   'Max Temp': 71.6,
#   'Humidity': 91,
#   'Cloudiness': 77,
#   'Wind Speed': 1.74,
#   'Current Description': 'broken clouds'},
#  {'City': 'Moron',
#   'Country': 'AR',
#   'Lat': -34.6534,
#   'Lng': -58.6198,
#   'Max Temp': 87.69,
#   'Humidity': 45,
#   'Cloudiness': 1,
#   'Wind Speed': 3,
#   'Current Description': 'clear sky'},
#  {'City': 'Tabuk',
#   'Country': 'PH',
#   'Lat': 17.4189,
#   'Lng': 121.4443,
#   'Max Temp': 74.12,
#   'Humidity': 90,
#   'Cloudiness': 56,
#   'Wind Speed': 2.37,
#   'Current Description': 'broken clouds'},
#  {'City': 'Nantucket',
#   'Country': 'US',
#   'Lat': 41.2835,
#   'Lng': -70.0995,
#   'Max Temp': 34.14,
#   'Humidity': 81,
#   'Cloudiness': 86,
#   'Wind Speed': 4.63,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Velingara',
#   'Country': 'SN',
#   'Lat': 13.15,
#   'Lng': -14.1167,
#   'Max Temp': 77.92,
#   'Humidity': 19,
#   'Cloudiness': 95,
#   'Wind Speed': 5.88,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bubaque',
#   'Country': 'GW',
#   'Lat': 11.2833,
#   'Lng': -15.8333,
#   'Max Temp': 80.67,
#   'Humidity': 70,
#   'Cloudiness': 84,
#   'Wind Speed': 10.38,
#   'Current Description': 'broken clouds'},
#  {'City': 'Hasaki',
#   'Country': 'JP',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 45,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 4.72,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Labuhan',
#   'Country': 'ID',
#   'Lat': -6.8844,
#   'Lng': 112.2051,
#   'Max Temp': 80.94,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 4.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mae Sai',
#   'Country': 'TH',
#   'Lat': 20.4335,
#   'Lng': 99.8762,
#   'Max Temp': 60.44,
#   'Humidity': 84,
#   'Cloudiness': 96,
#   'Wind Speed': 1.12,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Faanui',
#   'Country': 'PF',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 82.44,
#   'Humidity': 70,
#   'Cloudiness': 53,
#   'Wind Speed': 14.83,
#   'Current Description': 'broken clouds'},
#  {'City': 'Vangaindrano',
#   'Country': 'MG',
#   'Lat': -23.35,
#   'Lng': 47.6,
#   'Max Temp': 75.02,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 2.82,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Toora-Khem',
#   'Country': 'RU',
#   'Lat': 52.4675,
#   'Lng': 96.11,
#   'Max Temp': -24.65,
#   'Humidity': 100,
#   'Cloudiness': 77,
#   'Wind Speed': 1.21,
#   'Current Description': 'broken clouds'},
#  {'City': 'Charters Towers',
#   'Country': 'AU',
#   'Lat': -20.1,
#   'Lng': 146.2667,
#   'Max Temp': 87.76,
#   'Humidity': 49,
#   'Cloudiness': 82,
#   'Wind Speed': 11.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Cidreira',
#   'Country': 'BR',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 70.86,
#   'Humidity': 73,
#   'Cloudiness': 4,
#   'Wind Speed': 16.4,
#   'Current Description': 'clear sky'},
#  {'City': 'Guamuchil',
#   'Country': 'MX',
#   'Lat': 25.4667,
#   'Lng': -108.1,
#   'Max Temp': 77.76,
#   'Humidity': 41,
#   'Cloudiness': 88,
#   'Wind Speed': 6.69,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Namie',
#   'Country': 'JP',
#   'Lat': 37.4833,
#   'Lng': 141,
#   'Max Temp': 45.97,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 12.68,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Codrington',
#   'Country': 'AU',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 61.83,
#   'Humidity': 76,
#   'Cloudiness': 68,
#   'Wind Speed': 14.92,
#   'Current Description': 'broken clouds'},
#  {'City': 'Santa Marta',
#   'Country': 'CO',
#   'Lat': 11.2408,
#   'Lng': -74.199,
#   'Max Temp': 78.51,
#   'Humidity': 87,
#   'Cloudiness': 77,
#   'Wind Speed': 14.43,
#   'Current Description': 'broken clouds'},
#  {'City': 'San Lorenzo',
#   'Country': 'PY',
#   'Lat': -25.3333,
#   'Lng': -57.5333,
#   'Max Temp': 79.59,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 4.12,
#   'Current Description': 'clear sky'},
#  {'City': 'Ilulissat',
#   'Country': 'GL',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 26.62,
#   'Humidity': 31,
#   'Cloudiness': 24,
#   'Wind Speed': 5.75,
#   'Current Description': 'few clouds'},
#  {'City': 'Tolaga Bay',
#   'Country': 'NZ',
#   'Lat': -38.3667,
#   'Lng': 178.3,
#   'Max Temp': 66.99,
#   'Humidity': 75,
#   'Cloudiness': 98,
#   'Wind Speed': 13.89,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Candelaria',
#   'Country': 'PH',
#   'Lat': 13.9311,
#   'Lng': 121.4233,
#   'Max Temp': 79.39,
#   'Humidity': 83,
#   'Cloudiness': 41,
#   'Wind Speed': 6.91,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Aklavik',
#   'Country': 'CA',
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': -8.68,
#   'Humidity': 95,
#   'Cloudiness': 100,
# ...
#   'Max Temp': 34.93,
#   'Humidity': 88,
#   'Cloudiness': 78,
#   'Wind Speed': 7.14,
#   'Current Description': 'broken clouds'},
#  {'City': 'Nicoya',
#   'Country': 'CR',
#   'Lat': 10.1483,
#   'Lng': -85.452,
#   'Max Temp': 80.15,
#   'Humidity': 74,
#   'Cloudiness': 57,
#   'Wind Speed': 5.88,
#   'Current Description': 'broken clouds'},
#  {'City': 'Nombre De Dios',
#   'Country': 'MX',
#   'Lat': 23.85,
#   'Lng': -104.2333,
#   'Max Temp': 80.15,
#   'Humidity': 21,
#   'Cloudiness': 79,
#   'Wind Speed': 4.68,
#   'Current Description': 'broken clouds'},
#  {'City': 'Aykhal',
#   'Country': 'RU',
#   'Lat': 66,
#   'Lng': 111.5,
#   'Max Temp': -17.54,
#   'Humidity': 89,
#   'Cloudiness': 25,
#   'Wind Speed': 5.55,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Coahuayana',
#   'Country': 'MX',
#   'Lat': 18.7333,
#   'Lng': -103.6833,
#   'Max Temp': 83.68,
#   'Humidity': 71,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Zambezi',
#   'Country': 'ZM',
#   'Lat': -13.5432,
#   'Lng': 23.1047,
#   'Max Temp': 65.19,
#   'Humidity': 98,
#   'Cloudiness': 99,
#   'Wind Speed': 4.83,
#   'Current Description': 'moderate rain'},
#  {'City': 'Urengoy',
#   'Country': 'RU',
#   'Lat': 65.9667,
#   'Lng': 78.3667,
#   'Max Temp': 10.53,
#   'Humidity': 89,
#   'Cloudiness': 99,
#   'Wind Speed': 18.16,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Muhos',
#   'Country': 'FI',
#   'Lat': 64.808,
#   'Lng': 25.9931,
#   'Max Temp': 14.7,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 7.96,
#   'Current Description': 'light snow'},
#  {'City': 'Weligama',
#   'Country': 'LK',
#   'Lat': 5.9667,
#   'Lng': 80.4167,
#   'Max Temp': 73.51,
#   'Humidity': 88,
#   'Cloudiness': 83,
#   'Wind Speed': 4.74,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ulaangom',
#   'Country': 'MN',
#   'Lat': 49.9811,
#   'Lng': 92.0667,
#   'Max Temp': -11.38,
#   'Humidity': 91,
#   'Cloudiness': 92,
#   'Wind Speed': 3.69,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Maputo',
#   'Country': 'MZ',
#   'Lat': -25.9653,
#   'Lng': 32.5892,
#   'Max Temp': 72.23,
#   'Humidity': 84,
#   'Cloudiness': 80,
#   'Wind Speed': 1.01,
#   'Current Description': 'broken clouds'},
#  {'City': 'Simao',
#   'Country': 'CN',
#   'Lat': 22.7886,
#   'Lng': 100.9748,
#   'Max Temp': 47.7,
#   'Humidity': 95,
#   'Cloudiness': 36,
#   'Wind Speed': 1.05,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Nizhniy Odes',
#   'Country': 'RU',
#   'Lat': 63.6445,
#   'Lng': 54.856,
#   'Max Temp': -12.98,
#   'Humidity': 98,
#   'Cloudiness': 42,
#   'Wind Speed': 6.15,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Havoysund',
#   'Country': 'NO',
#   'Lat': 70.9963,
#   'Lng': 24.6622,
#   'Max Temp': 22.08,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 8.39,
#   'Current Description': 'light snow'},
#  {'City': 'Bone',
#   'Country': 'DE',
#   'Lat': 51.9669,
#   'Lng': 12.1396,
#   'Max Temp': 30.87,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 8.52,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Magadan',
#   'Country': 'RU',
#   'Lat': 59.5667,
#   'Lng': 150.8,
#   'Max Temp': -7.91,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 10.76,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Wucheng',
#   'Country': 'CN',
#   'Lat': 29.6008,
#   'Lng': 118.175,
#   'Max Temp': 37.81,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 6.33,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Waipawa',
#   'Country': 'NZ',
#   'Lat': -41.4122,
#   'Lng': 175.5153,
#   'Max Temp': 61.93,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 8.86,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dudinka',
#   'Country': 'RU',
#   'Lat': 69.4058,
#   'Lng': 86.1778,
#   'Max Temp': 16.63,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 13.35,
#   'Current Description': 'light snow'},
#  {'City': 'Umarkot',
#   'Country': 'PK',
#   'Lat': 25.3616,
#   'Lng': 69.7362,
#   'Max Temp': 62.64,
#   'Humidity': 24,
#   'Cloudiness': 5,
#   'Wind Speed': 6.6,
#   'Current Description': 'clear sky'},
#  {'City': 'Santa Maria',
#   'Country': 'BR',
#   'Lat': -29.6842,
#   'Lng': -53.8069,
#   'Max Temp': 70.38,
#   'Humidity': 52,
#   'Cloudiness': 1,
#   'Wind Speed': 5.06,
#   'Current Description': 'clear sky'},
#  {'City': 'San Felipe',
#   'Country': 'VE',
#   'Lat': 10.3399,
#   'Lng': -68.7425,
#   'Max Temp': 71.71,
#   'Humidity': 98,
#   'Cloudiness': 61,
#   'Wind Speed': 3.8,
#   'Current Description': 'broken clouds'},
#  {'City': 'Nefteyugansk',
#   'Country': 'RU',
#   'Lat': 61.0998,
#   'Lng': 72.6035,
#   'Max Temp': 3.45,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 19.3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mabay',
#   'Country': 'PH',
#   'Lat': 6.0577,
#   'Lng': 124.4666,
#   'Max Temp': 81,
#   'Humidity': 75,
#   'Cloudiness': 90,
#   'Wind Speed': 0.72,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Leglise',
#   'Country': 'BE',
#   'Lat': 49.7999,
#   'Lng': 5.5365,
#   'Max Temp': 45.16,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57,
#   'Current Description': 'light rain'},
#  {'City': 'Dicabisagan',
#   'Country': 'PH',
#   'Lat': 17.0818,
#   'Lng': 122.4157,
#   'Max Temp': 76.53,
#   'Humidity': 87,
#   'Cloudiness': 33,
#   'Wind Speed': 6.24,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Lavrentiya',
#   'Country': 'RU',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': 5.77,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 9.91,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pokrovsk',
#   'Country': 'UA',
#   'Lat': 48.282,
#   'Lng': 37.1758,
#   'Max Temp': 33.03,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 17.27,
#   'Current Description': 'snow'},
#  {'City': 'Neftcala',
#   'Country': 'AZ',
#   'Lat': 39.3742,
#   'Lng': 49.2472,
#   'Max Temp': 38.3,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 12.17,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ponta Delgada',
#   'Country': 'PT',
#   'Lat': 37.7333,
#   'Lng': -25.6667,
#   'Max Temp': 63.5,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mancheral',
#   'Country': 'IN',
#   'Lat': 18.8667,
#   'Lng': 79.4333,
#   'Max Temp': 62.8,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 2.57,
#   'Current Description': 'clear sky'},
#  {'City': 'Nichinan',
#   'Country': 'JP',
#   'Lat': 31.6,
#   'Lng': 131.3667,
#   'Max Temp': 51.48,
#   'Humidity': 73,
#   'Cloudiness': 69,
#   'Wind Speed': 14.54,
#   'Current Description': 'broken clouds'},
#  {'City': 'Road Town',
#   'Country': 'VG',
#   'Lat': 18.4167,
#   'Lng': -64.6167,
#   'Max Temp': 77.09,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Current Description': 'few clouds'},
#  {'City': 'Kamenka',
#   'Country': 'RU',
#   'Lat': 51.3223,
#   'Lng': 42.7678,
#   'Max Temp': 11.75,
#   'Humidity': 89,
#   'Cloudiness': 62,
#   'Wind Speed': 20.62,
#   'Current Description': 'broken clouds'},
#  {'City': 'Brasilia De Minas',
#   'Country': 'BR',
#   'Lat': -16.2064,
#   'Lng': -44.4333,
#   'Max Temp': 65.01,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Current Description': 'moderate rain'},
#  {'City': 'Jiuquan',
#   'Country': 'CN',
#   'Lat': 39.7432,
#   'Lng': 98.5174,
#   'Max Temp': 10.35,
#   'Humidity': 59,
#   'Cloudiness': 3,
#   'Wind Speed': 4.72,
#   'Current Description': 'clear sky'},
#  {'City': 'Arrifes',
#   'Country': 'PT',
#   'Lat': 37.7667,
#   'Lng': -25.7,
#   'Max Temp': 61.23,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds'},
#  {'City': 'Pittsburg',
#   'Country': 'US',
#   'Lat': 38.028,
#   'Lng': -121.8847,
#   'Max Temp': 55.26,
#   'Humidity': 73,
#   'Cloudiness': 90,
#   'Wind Speed': 4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Malko Tarnovo',
#   'Country': 'BG',
#   'Lat': 41.9833,
#   'Lng': 27.5333,
#   'Max Temp': 33.78,
#   'Humidity': 91,
#   'Cloudiness': 23,
#   'Wind Speed': 16.08,
#   'Current Description': 'few clouds'},
#  {'City': 'Montrose',
#   'Country': 'US',
#   'Lat': 38.4166,
#   'Lng': -108.2673,
#   'Max Temp': 32.36,
#   'Humidity': 95,
#   'Cloudiness': 98,
#   'Wind Speed': 9.73,
#   'Current Description': 'snow'},
#  {'City': 'Gagino',
#   'Country': 'RU',
#   'Lat': 55.2314,
#   'Lng': 45.0339,
#   'Max Temp': 2.89,
#   'Humidity': 86,
#   'Cloudiness': 9,
#   'Wind Speed': 17.13,
#   'Current Description': 'clear sky'},
#  {'City': 'Turayf',
#   'Country': 'SA',
#   'Lat': 31.6725,
#   'Lng': 38.6637,
#   'Max Temp': 39.45,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Khor',
#   'Country': 'RU',
#   'Lat': 47.8861,
#   'Lng': 134.9464,
#   'Max Temp': -21.42,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 5.61,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cururupu',
#   'Country': 'BR',
#   'Lat': -1.8283,
#   'Lng': -44.8683,
#   'Max Temp': 79.54,
#   'Humidity': 81,
#   'Cloudiness': 98,
#   'Wind Speed': 4.23,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Zhanaozen',
#   'Country': 'KZ',
#   'Lat': 43.3,
#   'Lng': 52.8,
#   'Max Temp': 19.33,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 12.12,
#   'Current Description': 'clear sky'},
#  {'City': 'Chino Valley',
#   'Country': 'US',
#   'Lat': 34.7575,
#   'Lng': -112.4538,
#   'Max Temp': 48.42,
#   'Humidity': 84,
#   'Cloudiness': 90,
#   'Wind Speed': 1.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Brigantine',
#   'Country': 'US',
#   'Lat': 39.4101,
#   'Lng': -74.3646,
#   'Max Temp': 45.01,
#   'Humidity': 85,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Tonj',
#   'Country': 'SS',
#   'Lat': 7.2737,
#   'Lng': 28.6822,
#   'Max Temp': 75.24,
#   'Humidity': 29,
#   'Cloudiness': 72,
#   'Wind Speed': 4.9,
#   'Current Description': 'broken clouds'},
#  {'City': 'Chara',
#   'Country': 'RU',
#   'Lat': 56.9064,
#   'Lng': 118.2631,
#   'Max Temp': -13.5,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 0.38,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Grants Pass',
#   'Country': 'US',
#   'Lat': 42.439,
#   'Lng': -123.3284,
#   'Max Temp': 39.9,
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Current Description': 'fog'},
#  {'City': 'Cowra',
#   'Country': 'AU',
#   'Lat': -33.8333,
#   'Lng': 148.6833,
#   'Max Temp': 85.26,
#   'Humidity': 39,
#   'Cloudiness': 22,
#   'Wind Speed': 6.26,
#   'Current Description': 'few clouds'},
#  {'City': 'Ha Giang',
#   'Country': 'VN',
#   'Lat': 22.8333,
#   'Lng': 104.9833,
#   'Max Temp': 63.01,
#   'Humidity': 95,
#   'Cloudiness': 73,
#   'Wind Speed': 0.11,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ejea De Los Caballeros',
#   'Country': 'ES',
#   'Lat': 42.1263,
#   'Lng': -1.1372,
#   'Max Temp': 49.86,
#   'Humidity': 87,
#   'Cloudiness': 91,
#   'Wind Speed': 7.45,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Canutama',
#   'Country': 'BR',
#   'Lat': -6.5339,
#   'Lng': -64.3831,
#   'Max Temp': 76.66,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 2.21,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nanlong',
#   'Country': 'CN',
#   'Lat': 31.3533,
#   'Lng': 106.0631,
#   'Max Temp': 49.28,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 7.18,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Atambua',
#   'Country': 'ID',
#   'Lat': -9.1061,
#   'Lng': 124.8925,
#   'Max Temp': 74.7,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 3.18,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Khasan',
#   'Country': 'RU',
#   'Lat': 42.4308,
#   'Lng': 130.6434,
#   'Max Temp': -3.23,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 27.96,
#   'Current Description': 'clear sky'},
#  {'City': 'Santa Fe',
#   'Country': 'AR',
#   'Lat': -31.6333,
#   'Lng': -60.7,
#   'Max Temp': 85.75,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 5.99,
#   'Current Description': 'light rain'},
#  {'City': 'Luena',
#   'Country': 'AO',
#   'Lat': -11.7833,
#   'Lng': 19.9167,
#   'Max Temp': 59.18,
#   'Humidity': 97,
#   'Cloudiness': 99,
#   'Wind Speed': 1.63,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nador',
#   'Country': 'MA',
#   'Lat': 35.174,
#   'Lng': -2.9287,
#   'Max Temp': 53.85,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Itoman',
#   'Country': 'JP',
#   'Lat': 26.1247,
#   'Lng': 127.6694,
#   'Max Temp': 66.22,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 29.93,
#   'Current Description': 'broken clouds'},
#  {'City': 'Filadelfia',
#   'Country': 'US',
#   'Lat': 39.9523,
#   'Lng': -75.1638,
#   'Max Temp': 46.15,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Current Description': 'broken clouds'},
#  {'City': 'Novoanninskiy',
#   'Country': 'RU',
#   'Lat': 50.5287,
#   'Lng': 42.6747,
#   'Max Temp': 12.56,
#   'Humidity': 89,
#   'Cloudiness': 77,
#   'Wind Speed': 19.98,
#   'Current Description': 'broken clouds'},
#  {'City': 'Naze',
#   'Country': 'JP',
#   'Lat': 28.3667,
#   'Lng': 129.4833,
#   'Max Temp': 59.92,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 24.76,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Leshukonskoye',
#   'Country': 'RU',
#   'Lat': 64.8989,
#   'Lng': 45.7622,
#   'Max Temp': 5.81,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 10,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Garachine',
#   'Country': 'PA',
#   'Lat': 8.0647,
#   'Lng': -78.3628,
#   'Max Temp': 79.75,
#   'Humidity': 85,
#   'Cloudiness': 65,
#   'Wind Speed': 9.33,
#   'Current Description': 'broken clouds'},
#  {'City': 'Christchurch',
#   'Country': 'NZ',
#   'Lat': -43.5333,
#   'Lng': 172.6333,
#   'Max Temp': 65.32,
#   'Humidity': 60,
#   'Cloudiness': 79,
#   'Wind Speed': 5.99,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tual',
#   'Country': 'ID',
#   'Lat': -5.6667,
#   'Lng': 132.75,
#   'Max Temp': 83.39,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 21.83,
#   'Current Description': 'light rain'},
#  {'City': 'Aljezur',
#   'Country': 'PT',
#   'Lat': 37.3191,
#   'Lng': -8.8033,
#   'Max Temp': 59.41,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 15.46,
#   'Current Description': 'light rain'},
#  {'City': 'La Sarre',
#   'Country': 'CA',
#   'Lat': 48.8002,
#   'Lng': -79.1996,
#   'Max Temp': 20.97,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 9.13,
#   'Current Description': 'light snow'},
#  {'City': 'Verin',
#   'Country': 'ES',
#   'Lat': 41.9415,
#   'Lng': -7.4381,
#   'Max Temp': 50.56,
#   'Humidity': 97,
#   'Cloudiness': 99,
#   'Wind Speed': 3.6,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Brookhaven',
#   'Country': 'US',
#   'Lat': 31.5791,
#   'Lng': -90.4407,
#   'Max Temp': 69.46,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 11.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Batemans Bay',
#   'Country': 'AU',
#   'Lat': -35.7167,
#   'Lng': 150.1833,
#   'Max Temp': 90.19,
#   'Humidity': 56,
#   'Cloudiness': 21,
#   'Wind Speed': 5.97,
#   'Current Description': 'few clouds'},
#  {'City': 'Urumqi',
#   'Country': 'CN',
#   'Lat': 43.801,
#   'Lng': 87.6005,
#   'Max Temp': 11.35,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 4.47,
#   'Current Description': 'fog'},
#  {'City': 'Egvekinot',
#   'Country': 'RU',
#   'Lat': 66.3167,
#   'Lng': -179.1667,
#   'Max Temp': -11.97,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 13.91,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Susanville',
#   'Country': 'US',
#   'Lat': 40.4163,
#   'Lng': -120.653,
#   'Max Temp': 37.09,
#   'Humidity': 72,
#   'Cloudiness': 90,
#   'Wind Speed': 17.27,
#   'Current Description': 'light snow'},
#  {'City': 'Riyadh',
#   'Country': 'SA',
#   'Lat': 24.6877,
#   'Lng': 46.7219,
#   'Max Temp': 62.74,
#   'Humidity': 46,
#   'Cloudiness': 100,
#   'Wind Speed': 1.81,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pemba',
#   'Country': 'MZ',
#   'Lat': -12.974,
#   'Lng': 40.5178,
#   'Max Temp': 78.6,
#   'Humidity': 86,
#   'Cloudiness': 47,
#   'Wind Speed': 8.52,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bagdarin',
#   'Country': 'RU',
#   'Lat': 54.4333,
#   'Lng': 113.6,
#   'Max Temp': -13.95,
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 3.87,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Terpinnya',
#   'Country': 'UA',
#   'Lat': 46.9697,
#   'Lng': 35.4197,
#   'Max Temp': 35.28,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 9.26,
#   'Current Description': 'overcast clouds'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Verkhoturye      RU  58.8627   60.8054      2.03        90          88
# 1    Cape Town      ZA -33.9258   18.4232     64.81        79           0
# 2       Putina      PE -15.4667  -69.4333     49.35        74          71
# 3    Taoudenni      ML  22.6783   -3.9836     68.38        25          89
# 4   Bredasdorp      ZA -34.5322   20.0403     61.29        90          78
# 5     Khatanga      RU  71.9667  102.5000    -28.82       100          13
# 6    Busselton      AU -33.6500  115.3333     73.04        48           0
# 7      Mataura      NZ -46.1927  168.8643     65.48        34           0
# 8       Broome      US  42.2506  -75.8330     36.68        73         100
# 9    Carnarvon      AU -24.8667  113.6333     80.22        68           0
#
#    Wind Speed Current Description
# 0       11.03     overcast clouds
# 1        1.99           clear sky
# 2        8.32          light rain
# 3        9.15     overcast clouds
# 4       12.30       broken clouds
# 5        5.53          few clouds
# 6       16.44           clear sky
# 7        3.33           clear sky
# 8        1.99     overcast clouds
# 9       12.06           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
