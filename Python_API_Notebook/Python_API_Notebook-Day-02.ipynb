# %% [markdown]
# # Day 02
# # Instructor Turn - 01- Requests Demo  - 👩‍🏫🧑‍🏫

# %%
# Dependencies
import requests
import json

# Google developer API key
from config import gkey

# Target city
target_city = "Boise, Idaho"

# Build the endpoint URL
target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format(target_city, gkey)

# %%
# Run a request to endpoint and convert result to json
geo_data = requests.get(target_url).json()

# Print the json
print(geo_data)
# Out:
# {'results': [{'address_components': [{'long_name': 'Boise', 'short_name': 'Boise', 'types': ['locality', 'political']}, {'long_name': 'Ada County', 'short_name': 'Ada County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Idaho', 'short_name': 'ID', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}], 'formatted_address': 'Boise, ID, USA', 'geometry': {'bounds': {'northeast': {'lat': 43.6898951, 'lng': -116.1019091}, 'southwest': {'lat': 43.511717, 'lng': -116.3658869}}, 'location': {'lat': 43.6150186, 'lng': -116.2023137}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 43.6898951, 'lng': -116.1019091}, 'southwest': {'lat': 43.511717, 'lng': -116.3658869}}}, 'place_id': 'ChIJnbRH6XLxrlQRm51nNpuYW5o', 'types': ['locality', 'political']}], 'status': 'OK'}

# %%
# Print the json (pretty printed)
print(json.dumps(geo_data, indent=4, sort_keys=True))
# Out:
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Boise",
#                     "short_name": "Boise",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Ada County",
#                     "short_name": "Ada County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Idaho",
#                     "short_name": "ID",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Boise, ID, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 43.6898951,
#                         "lng": -116.1019091
#                     },
#                     "southwest": {
#                         "lat": 43.511717,
#                         "lng": -116.3658869
#                     }
#                 },
#                 "location": {
#                     "lat": 43.6150186,
#                     "lng": -116.2023137
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.6898951,
#                         "lng": -116.1019091
#                     },
#                     "southwest": {
#                         "lat": 43.511717,
#                         "lng": -116.3658869
#                     }
#                 }
#             },
#             "place_id": "ChIJnbRH6XLxrlQRm51nNpuYW5o",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }

# %%
# Extract latitude and longitude
lat = geo_data["results"][0]["geometry"]["location"]["lat"]
lng = geo_data["results"][0]["geometry"]["location"]["lng"]

# Print the city, latitude and longitude
print(f'City: {target_city} Latitude: {lat}, Longitude: {lng}')
# Out:
# City: Boise, Idaho Latitude: 43.6150186, Longitude: -116.2023137

# %% [markdown]
# # Instructor Turn - 02 - Google Places - 👩‍🏫🧑‍🏫

# %%
# Dependencies
import requests
import json

# Google developer API key
from config import gkey

# %%
# geocoordinates
target_coordinates = "43.6187102, -116.2146068"
target_search = "Chinese"
target_radius = 8000
target_type = "restaurant"

# %%
# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# %%
# run a request using our params dictionary
response = requests.get(base_url, params=params)

# convert response to json
places_data = response.json()

# %%
# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "Aap_uEBCY1w2CeS21_nap8jji5Y9V8fAnEEJxSdDbJgoWhi4OvMfJkA3O_hND0-F69xSo3P3miRyuSyhrCcHDWLJRakJAx72Z1MniBZ5V1AhSXMZqfOnZbNvx8XSvczzhoP4kld_nS1ypFgwJlYONgJZUADyVRqBCXZpIR6nzXukC1MO9ATvVJhBLQxEwY3VBt4j7l7ea-DHLz7cs1HHp9B1dcKYAddWuETo6L513EMNnKLylNGemLvA6i8l8HIA3Wlo9RI9JQW1aEY47m2zDGi7HO3l0Gg89fzC-mazsbgu0fHge9iWew7J0uNC9GdCBUjUbPBbPGDm1ufpB9AXRaVY_vwGi8jIpHvxCLWESnYLvHfTCrL2h7mJMiiRrnEA6GoI7eY0x0sw14VdWt5fgeBxJ5CVxCJixDgcwzQRgXHb6P0ojIh_oQX9xWDH-4vvQmIIGBPdHMdHFWuWYLBtFaAyZJkjM-uCLmnaUlVoCheYqD1hPpEUBY5vkz51puKo8282Fy9j2SoXwuF2nCAVzf3YYS4mMipqDDeS_XUKBIblIHjdGhSlMXk7MUvPkTUPo2hF58IZ9gavbIbnj9gBC3p-BQwJGRDBPIlKncj42JFFWXGN8U9bnk4wnBBQ26IBORLCOELXuo5Mjl3dJLbQY7h1yWMByN_zgfO2GzlbTtsqlSQcxMbQ-feWzOdWGTL8Lhigv5Fn15C2BPKrBa9ZokDAuXuVOy9BGqxuExhwUxTeKoKM3CFid38KSr7sPtvD",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.5888893,
#                     "lng": -116.2776039
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.59032242989273,
#                         "lng": -116.2762745201073
#                     },
#                     "southwest": {
#                         "lat": 43.58762277010728,
#                         "lng": -116.2789741798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "Guang Zhou Restaurant",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101811418303658757333\">Alex Inskeep</a>"
#                     ],
#                     "photo_reference": "Aap_uEBwwkdeJtfPhyt-XIEuxhtj3lkAvErJdN34LXbeaPgImnLIz-BmVrwpE-ZOMAppy8nGyYTKxN2zt-SAaQjydhfC5WAY9Ug9tLUShclgXWUG3I_ZGjWPGGBeDL79Hgz0LDwE2N4ojwuFT8klCzpXHdv-87LjyF3Ql3WU4-zZO0reoE04",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJDT-7DlJWrlQRO7rtBTzZf6s",
#             "plus_code": {
#                 "compound_code": "HPQC+HX Boise, Idaho",
#                 "global_code": "85M5HPQC+HX"
#             },
#             "price_level": 1,
#             "rating": 4.1,
#             "reference": "ChIJDT-7DlJWrlQRO7rtBTzZf6s",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 443,
#             "vicinity": "7609 W Overland Rd, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.6487584,
#                     "lng": -116.2461602
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.65001942989272,
#                         "lng": -116.2449492201073
#                     },
#                     "southwest": {
#                         "lat": 43.64731977010727,
#                         "lng": -116.2476488798928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "New Garden Chinese Restaurant",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4160,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110284797720925008141\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uEBUsZo6kBR0KZNIrC6njEaNf0OP7JB2A7TqIlzVP0lrhy-ojLrcHJSh6HrYW2BOxX6qfklzfTlqk08kbsacmzdQgj_OSLHeVAl_UzMGB2M-XXNJm8mpeOlAYwF8ZW41VoSkYDnSxYB9t45xgrypqrLS8r9NzQu-SlnGNfu_DuOdAJ8e",
#                     "width": 3120
#                 }
#             ],
#             "place_id": "ChIJvwYXUDz_rlQRKpVyY618JMM",
#             "plus_code": {
#                 "compound_code": "JQX3+GG Boise, Idaho",
#                 "global_code": "85M5JQX3+GG"
#             },
#             "price_level": 1,
#             "rating": 3.9,
#             "reference": "ChIJvwYXUDz_rlQRKpVyY618JMM",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 165,
#             "vicinity": "4624 W State St, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.6251218,
#                     "lng": -116.2123933
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.62632297989272,
#                         "lng": -116.2111938701073
#                     },
#                     "southwest": {
#                         "lat": 43.62362332010727,
#                         "lng": -116.2138935298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "North End Chinese Restaurant",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3264,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102960671513587619713\">Nicholas DiPietro</a>"
#                     ],
#                     "photo_reference": "Aap_uEBikmNUpTS4W43RudoE8Nxm-vpOMVfp3n8AHySOrFGagSS0bdPJ67_ddx02JpkspEcUJKrrqsgi39nbnY-KrbstSTrDUjS0JCsPTgH7s45MLZ_PEojNzm9L-90zSuy3qtSF6sZ7O2qIfh1nmW9goCIwgUznTTpMOHAKLD8demDYXgZD",
#                     "width": 2448
#                 }
#             ],
#             "place_id": "ChIJP5lMQNz4rlQRPRigHmorMWw",
#             "plus_code": {
#                 "compound_code": "JQGQ+22 Boise, Idaho",
#                 "global_code": "85M5JQGQ+22"
#             },
#             "price_level": 1,
#             "rating": 3.9,
#             "reference": "ChIJP5lMQNz4rlQRPRigHmorMWw",
#             "scope": "GOOGLE",
#             "types": [
#                 "meal_delivery",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 245,
#             "vicinity": "1806 W State St #3955, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.62829869999999,
#                     "lng": -116.2467501
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.62964852989272,
#                         "lng": -116.2454002701073
#                     },
#                     "southwest": {
#                         "lat": 43.62694887010727,
#                         "lng": -116.2480999298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "Golden Wok",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108564864349711743478\">Trang Pham</a>"
#                     ],
#                     "photo_reference": "Aap_uEBEAEhIrpk0TLZ_ZCAmtGSSiIBNrTHBlXI4nAxgtEeAbbhhsTjO--3elXuboqmNyqb-CIfBh1cU-BwPtRPlsrsVJS5b7xJbppIRZzYbBpV0mE50r60mvRsRa0RenG1mR0REakAkFl7rUK5btxhzcK-wngl1kqYFhMK4Yphcv5gvxrKx",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJ4-wGxrP4rlQRQBpLRX5r_t0",
#             "plus_code": {
#                 "compound_code": "JQH3+87 Boise, Idaho",
#                 "global_code": "85M5JQH3+87"
#             },
#             "price_level": 1,
#             "rating": 4,
#             "reference": "ChIJ4-wGxrP4rlQRQBpLRX5r_t0",
#             "scope": "GOOGLE",
#             "types": [
#                 "meal_delivery",
#                 "meal_takeaway",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 460,
#             "vicinity": "3948 W Chinden Blvd #6412, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.577295,
#                     "lng": -116.195009
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.57901292989273,
#                         "lng": -116.1936632701073
#                     },
#                     "southwest": {
#                         "lat": 43.57631327010728,
#                         "lng": -116.1963629298928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "Season Wok",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1208,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117474966032883412922\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uEBFhiUZTpPzAP8aabM-i5-8T3ojbSchPyXlh1ud7_VWzmR3deNgOFHcnHB7oIInhoi3OYi1Fo0eugkLtgSXtbs0bexVbSNENwQALPn1_HkYc6hU8HI_fiikgEtZepS8JL14jvQEQK0xPuU7131z0FK6ORNcSMSMWVkvemnWh3kwyXsx",
#                     "width": 1074
#                 }
#             ],
#             "place_id": "ChIJ_9TdpxD4rlQRdg8ROoJbNSw",
#             "plus_code": {
#                 "compound_code": "HRG3+WX Boise, Idaho",
#                 "global_code": "85M5HRG3+WX"
#             },
#             "price_level": 1,
#             "rating": 3.5,
#             "reference": "ChIJ_9TdpxD4rlQRdg8ROoJbNSw",
#             "scope": "GOOGLE",
#             "types": [
#                 "meal_delivery",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 166,
#             "vicinity": "2775 Broadway Ave, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.5910063,
#                     "lng": -116.2900003
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.59235617989272,
#                         "lng": -116.2885996701073
#                     },
#                     "southwest": {
#                         "lat": 43.58965652010728,
#                         "lng": -116.2912993298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "Lucky Palace Chinese Restaurant",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2534,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116258063497492904062\">hyt5168</a>"
#                     ],
#                     "photo_reference": "Aap_uEBE7WGwUaTip7MCmEWqB0QhJlmaLcOpTHKJSsDIw33aReMYoirYpO-6NohctaCS8ezviKmrtimVQzBO77gnEjQ3xpn3cKs3wdMtBX6shWd4ExwojB8-UGbQjlwN9ACJFDVMBlmzZWpoMCrMz6FYaTpFCyHTJz4L2GW7U1opW-xrE5i2",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJ5RKyTVZWrlQRY-t-LLVVQ9M",
#             "plus_code": {
#                 "compound_code": "HPR5+CX Boise, Idaho",
#                 "global_code": "85M5HPR5+CX"
#             },
#             "price_level": 2,
#             "rating": 3.9,
#             "reference": "ChIJ5RKyTVZWrlQRY-t-LLVVQ9M",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 198,
#             "vicinity": "8630 W Overland Rd, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.58963800000001,
#                     "lng": -116.216586
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.59101702989273,
#                         "lng": -116.2151431201073
#                     },
#                     "southwest": {
#                         "lat": 43.58831737010728,
#                         "lng": -116.2178427798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "Panda Garden",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104209746584677475752\">Craig Lowary</a>"
#                     ],
#                     "photo_reference": "Aap_uEAGGBSCsc354B4JcFsMu8UQjTO3izMBmE_aEgpCgb7awya-bKVIIW_7GbEgvR0kg2wkDG_JoSqreEpAEv0SlYnXqfGZdJs3Uk4xubi7tuXsqDxxep-he1RdH7Qc5vUXTt8BlmVf4wtFNqjmAWmL7yAbQ5r8gCJFeWISmajbAcPC_oUe",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJ2VoTQ3D4rlQR3UKIMJlQFeI",
#             "plus_code": {
#                 "compound_code": "HQQM+V9 Boise, Idaho",
#                 "global_code": "85M5HQQM+V9"
#             },
#             "price_level": 1,
#             "rating": 4,
#             "reference": "ChIJ2VoTQ3D4rlQR3UKIMJlQFeI",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 394,
#             "vicinity": "2801 W Overland Rd, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.5906484,
#                     "lng": -116.2801612
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.59196002989272,
#                         "lng": -116.2788730701073
#                     },
#                     "southwest": {
#                         "lat": 43.58926037010728,
#                         "lng": -116.2815727298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "Panda Express",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 282,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109235819106383651889\">\u4e2d\u91ce\u7adc</a>"
#                     ],
#                     "photo_reference": "Aap_uEBO4pHYzs7i49O-LMYKfUxV8NWZZ0nVJmo06FYD7-OaAMiIAUrdLhQFXQvDHqMQ0fN9qUoRv81fniNmuMpBSN1SufMcteuUMKlY-BDkxDCpHru-BwNKI3aM6gSbbFNZ1wfd8K5zmeqzluba0NPXj8Ev3aceRmh0NIuMxct9F4QnQv2X",
#                     "width": 448
#                 }
#             ],
#             "place_id": "ChIJb15nIlJWrlQRcvGGNq_0WC8",
#             "plus_code": {
#                 "compound_code": "HPR9+7W Boise, Idaho",
#                 "global_code": "85M5HPR9+7W"
#             },
#             "price_level": 1,
#             "rating": 4.1,
#             "reference": "ChIJb15nIlJWrlQRcvGGNq_0WC8",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1057,
#             "vicinity": "7804 W Overland Rd, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.589956,
#                     "lng": -116.241835
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.59120952989272,
#                         "lng": -116.2405126701073
#                     },
#                     "southwest": {
#                         "lat": 43.58850987010727,
#                         "lng": -116.2432123298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "Quik-Wok Restaurant",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104596854037149095654\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uEDkUKah5u6iF00rTgmnZOJKhF_mBEY_OctV7nxdjnRzsZNdq84OPt_zhqlnGm7d-RVAKXJSURBv33567HPJ2x1uDki_UF0JumdAuzkb_xqCGSp07o0f3I7x0cElOpZilz7_4EtVaUkXTKLnEnPG6EcLHH28QdYhSEymqkfiy5dzS-UP",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJbRshL9JXrlQRDa61aB-RK2E",
#             "plus_code": {
#                 "compound_code": "HQQ5+X7 Boise, Idaho",
#                 "global_code": "85M5HQQ5+X7"
#             },
#             "price_level": 2,
#             "rating": 3.4,
#             "reference": "ChIJbRshL9JXrlQRDa61aB-RK2E",
#             "scope": "GOOGLE",
#             "types": [
#                 "meal_delivery",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 412,
#             "vicinity": "4858 W Overland Rd, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.6029245,
#                     "lng": -116.2444675
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.60422497989273,
#                         "lng": -116.2431192701073
#                     },
#                     "southwest": {
#                         "lat": 43.60152532010729,
#                         "lng": -116.2458189298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "Mandarin Palace",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2274,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103311480146692398200\">A Google User</a>"
#                     ],
#                     "photo_reference": "Aap_uEAcXk7qPw8luGPr8mhls3Qc7YVxffxT-UDh6KuHX-tpwhBRvZ69Wb8V10Aepa7HjJTNOthjE1_E7VsCq_aTsh_reu5TbojWjiII1Pbiru8oLR4HJPWAAUexVV91Sa0AP_84SpbSMwUzaTpHHInMSGi9-Ng-1OOw2K1DAUffTgmkNB0s",
#                     "width": 3095
#                 }
#             ],
#             "place_id": "ChIJecwebShWrlQRo_MtO2S0rdA",
#             "plus_code": {
#                 "compound_code": "JQ34+56 Boise, Idaho",
#                 "global_code": "85M5JQ34+56"
#             },
#             "price_level": 1,
#             "rating": 3.8,
#             "reference": "ChIJecwebShWrlQRo_MtO2S0rdA",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 274,
#             "vicinity": "5020 W. Franklin St., Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.6149025,
#                     "lng": -116.2427673
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.61625077989272,
#                         "lng": -116.2415218701072
#                     },
#                     "southwest": {
#                         "lat": 43.61355112010728,
#                         "lng": -116.2442215298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "Golden Star Restaurant",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4608,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112010777321852232295\">Raquel Perez</a>"
#                     ],
#                     "photo_reference": "Aap_uECaUZqCDkFWcqeCNLT95ECw9wQXAGWlBwJ99iTTqtK5XteMKn8V-UFlzs83-DL4dZt9WNYhYb34dhmgilNY7P7QcqOAdGe4xf_D3Ehe2jxMabno2krMhwz_q5_Wu0D6LkUK90J5Fg71J4KB6gCNOi7cU4NpZhsy_aBePoGrNyOEQZkw",
#                     "width": 3456
#                 }
#             ],
#             "place_id": "ChIJTctsXaL4rlQRbC1U996y4-0",
#             "plus_code": {
#                 "compound_code": "JQ74+XV Boise, Idaho",
#                 "global_code": "85M5JQ74+XV"
#             },
#             "price_level": 2,
#             "rating": 4.3,
#             "reference": "ChIJTctsXaL4rlQRbC1U996y4-0",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 863,
#             "vicinity": "1142 N Orchard St, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.6123556,
#                     "lng": -116.2430374
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.61360837989272,
#                         "lng": -116.2416783201072
#                     },
#                     "southwest": {
#                         "lat": 43.61090872010728,
#                         "lng": -116.2443779798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "Wok-Inn Noodle",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2327,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115594850829248502065\">Matthew Reed</a>"
#                     ],
#                     "photo_reference": "Aap_uEDmVTKgy1WrXe8cCuXUzhMkJllRjljV3_c6cF_ak7ZC2Yvwm8-SHJ9FGc8Cnw69rzTGGke_BHnJ1RA3bBSugZDO-zOXI4z3FJhYcZy9NXYuGTz7JiBWFEC2SQ_UIQWucWKZutSogXe8dD0JCCiT0v4rVMfgLZLD6ZqpuvEgJ5hRJBYP",
#                     "width": 2149
#                 }
#             ],
#             "place_id": "ChIJe9STjx9WrlQRnMGkKZFN9V4",
#             "plus_code": {
#                 "compound_code": "JQ64+WQ Boise, Idaho",
#                 "global_code": "85M5JQ64+WQ"
#             },
#             "price_level": 1,
#             "rating": 4.4,
#             "reference": "ChIJe9STjx9WrlQRnMGkKZFN9V4",
#             "scope": "GOOGLE",
#             "types": [
#                 "meal_takeaway",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 279,
#             "vicinity": "4912 Emerald St, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.6200457,
#                     "lng": -116.3128558
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.62137212989272,
#                         "lng": -116.3116427201073
#                     },
#                     "southwest": {
#                         "lat": 43.61867247010728,
#                         "lng": -116.3143423798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "China Grand Buffet",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113139047208396639642\">Stephen Newcomb</a>"
#                     ],
#                     "photo_reference": "Aap_uEAKWZBBAueZiUrGa9BmGwF63kEXaduXEoGSNy9ALdYfXg3OSHf5-1Jv813fXpILvd2Op9DI7fCA7v-Xh1qQK-87DWJkfAQw3eivYkk4CUWueUzFqQLsLw_C9ok80sK_CfQTlTfaJcAJSI491S0ZQ2bQZs7F2vbf646kBmAH52rMQNCE",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJTSFfGNRVrlQRuTYkj0zGqMM",
#             "plus_code": {
#                 "compound_code": "JMCP+2V Boise, Idaho",
#                 "global_code": "85M5JMCP+2V"
#             },
#             "price_level": 1,
#             "rating": 4.1,
#             "reference": "ChIJTSFfGNRVrlQRuTYkj0zGqMM",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2391,
#             "vicinity": "10498 W Fairview Ave, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.614921,
#                     "lng": -116.2838702
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.61626807989271,
#                         "lng": -116.2823547201073
#                     },
#                     "southwest": {
#                         "lat": 43.61356842010727,
#                         "lng": -116.2850543798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "Panda Express",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118350779690464862712\">Roxana Curtis</a>"
#                     ],
#                     "photo_reference": "Aap_uEC1zOKnYJSCKHdFDsoKZki_SVlYoyVgN2Vw0Yh6qqO3FvW2oG4WbkXqe4M9lF9mDZBd6WsDomUaSlzD-626NcFfINXVRVV2eTvu-H55XIeo3h0ZuL44sq_aEtoNmnYPm7LeUit2dpSckdQBkazSABCtN19axHr_T_Ndlf3uo6sFYvaR",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJbdZEMQ1WrlQRcVfVf-Hl8g8",
#             "plus_code": {
#                 "compound_code": "JP78+XF Boise, Idaho",
#                 "global_code": "85M5JP78+XF"
#             },
#             "price_level": 1,
#             "rating": 4,
#             "reference": "ChIJbdZEMQ1WrlQRcVfVf-Hl8g8",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 453,
#             "vicinity": "1124 N Milwaukee St, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.6180738,
#                     "lng": -116.2031764
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.61929437989272,
#                         "lng": -116.2017993701073
#                     },
#                     "southwest": {
#                         "lat": 43.61659472010727,
#                         "lng": -116.2044990298928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "Yen Ching Restaurant",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2273,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116258063497492904062\">hyt5168</a>"
#                     ],
#                     "photo_reference": "Aap_uECd2gigQTf6lPXfTbWGQQ2dYfz88vAqZBINiHZzVEna2ep2_0HPhUaeumbyMun4Pmk2nKCNxy4EY4tvA4vAAhzEz6D2aXCkDmd5KNw8D2dKEVSGiz_-QftWo3d0yu6KZN5AqH6WQ7nzcy4cf5tSXFYa2D0gy4qsp30bEYPcpZHK4ePY",
#                     "width": 3099
#                 }
#             ],
#             "place_id": "ChIJD1s29-P4rlQR0QVGxC9AWY0",
#             "plus_code": {
#                 "compound_code": "JQ9W+6P Boise, Idaho",
#                 "global_code": "85M5JQ9W+6P"
#             },
#             "price_level": 2,
#             "rating": 4.3,
#             "reference": "ChIJD1s29-P4rlQR0QVGxC9AWY0",
#             "scope": "GOOGLE",
#             "types": [
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 537,
#             "vicinity": "305 N 9th St, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.6128764,
#                     "lng": -116.2031451
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.61424682989271,
#                         "lng": -116.2016703201073
#                     },
#                     "southwest": {
#                         "lat": 43.61154717010727,
#                         "lng": -116.2043699798927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "Panda Express",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109602180627241753122\">Christapher Clark</a>"
#                     ],
#                     "photo_reference": "Aap_uEAnTtv-e0xiZioCZFjy7mDUFWy2umNaf95ClslEAsektne8cHTWi72oIIX9gxtDfZRQ1UBhi0syK12Fw-81jIGsLxmxh6awX0jtmDP6jGrN1OR93xlAR9PE1T69vHKL5rJy1JBwKV2uLhZB29coYs1BRx8641AqhQYmHfAAXFmdYmBp",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJkevL-_r4rlQRdCX2O8ZXDsM",
#             "plus_code": {
#                 "compound_code": "JQ7W+5P Boise, Idaho",
#                 "global_code": "85M5JQ7W+5P"
#             },
#             "price_level": 1,
#             "rating": 4,
#             "reference": "ChIJkevL-_r4rlQRdCX2O8ZXDsM",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 256,
#             "vicinity": "601 W Front St, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.6136713,
#                     "lng": -116.2057373
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.61494307989273,
#                         "lng": -116.2042832701073
#                     },
#                     "southwest": {
#                         "lat": 43.61224342010728,
#                         "lng": -116.2069829298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "P.F. Chang's",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105137345884947048400\">Zeb Palmer</a>"
#                     ],
#                     "photo_reference": "Aap_uECQ6eurYTvAULzixvJSJfF1Lwvw09fjaZClK8axYDQyhzQcDeFpxFI9VoDZo-YJNmbbjstn16-eOSAKAgz4tun-EPSPboQaZe4hhUIkO_AaudzA6Cxnf58g8w60a46BTQXVKNoG40LFXoLPVGGEhSNKPV9dHaJfOQZ9GW_T4mZJzetF",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJEVx3TeX4rlQR4QkPYThohEg",
#             "plus_code": {
#                 "compound_code": "JQ7V+FP Boise, Idaho",
#                 "global_code": "85M5JQ7V+FP"
#             },
#             "price_level": 2,
#             "rating": 4.2,
#             "reference": "ChIJEVx3TeX4rlQR4QkPYThohEg",
#             "scope": "GOOGLE",
#             "types": [
#                 "meal_delivery",
#                 "meal_takeaway",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1410,
#             "vicinity": "391 S 8th St, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.6653862,
#                     "lng": -116.2801056
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.66673117989272,
#                         "lng": -116.2785765701072
#                     },
#                     "southwest": {
#                         "lat": 43.66403152010727,
#                         "lng": -116.2812762298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "Panda Express",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108427894577938186722\">Xiaobai T</a>"
#                     ],
#                     "photo_reference": "Aap_uECjzdC6EE7SXN8OnndDdAIwgkDI-FbzDw04WQMzbsHYCO70f-qqDfRFaJdeh7zKNDxSx2LFO7m3UZ9AAR53w9blZkMSjf1_SQHyk31AmuhjC3JDJ05vMMSoy8OixxCS9dPHqC-iSij8D8kPGyMzR6xDfdW0JxpqSwJNWfQ3hXZZldfy",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJLdWyiJ7_rlQRIRdU-1NWqEw",
#             "plus_code": {
#                 "compound_code": "MP89+5X Garden City, Idaho",
#                 "global_code": "85M5MP89+5X"
#             },
#             "price_level": 1,
#             "rating": 4.1,
#             "reference": "ChIJLdWyiJ7_rlQRIRdU-1NWqEw",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 514,
#             "vicinity": "6675 N Glenwood St, Garden City"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.5915577,
#                     "lng": -116.3116912
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.59287852989272,
#                         "lng": -116.3105545701073
#                     },
#                     "southwest": {
#                         "lat": 43.59017887010728,
#                         "lng": -116.3132542298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "Great Wall Restaurant",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1152,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109235819106383651889\">RYU</a>"
#                     ],
#                     "photo_reference": "Aap_uEAsjonWbrqxcabW-UGIuxDdz990mOCRK8RzLTa7LpXEQoAkUMgmeYI3NTs1ZkHZkSsQq1MtNp1jH-G3b_8krFm0zuv-q8e1QLhrY2oaqtEICVPAkcBXueBtH_slGQjuGckvwNTRLReVOOdleKOh29gOLt01HBwOX3lLKuQDxyFQnwQe",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJle9LyO5WrlQRyBqJqPmCLQI",
#             "plus_code": {
#                 "compound_code": "HMRQ+J8 Boise, Idaho",
#                 "global_code": "85M5HMRQ+J8"
#             },
#             "price_level": 1,
#             "rating": 3.9,
#             "reference": "ChIJle9LyO5WrlQRyBqJqPmCLQI",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 763,
#             "vicinity": "10398 W Overland Rd, Boise"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.60734859999999,
#                     "lng": -116.2787673
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.60860872989272,
#                         "lng": -116.2775648701073
#                     },
#                     "southwest": {
#                         "lat": 43.60590907010727,
#                         "lng": -116.2802645298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "icon_background_color": "#FF9E67",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#             "name": "Panda Express",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104961771114871630072\">Bobbie Owen</a>"
#                     ],
#                     "photo_reference": "Aap_uEBLmknPn5PTHIQ42HEJaw7SIxZjMPKTiUQvv1qNx1zNIo0N8_UJ9Ftul9GFEKFU6UKb72xmfl3wwoJKmebWpccAGeGA5KZc_2o2gnK-5jhBz9m36gfJB-uh4kL9JjDGe4KWieo7_nTEQ8wfp4oiyZlGOfNH1sIlFXMWasXFaGqbSw6M",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJfYBLkWpWrlQRjig0x7oVFfk",
#             "plus_code": {
#                 "compound_code": "JP4C+WF Boise, Idaho",
#                 "global_code": "85M5JP4C+WF"
#             },
#             "price_level": 1,
#             "rating": 3.3,
#             "reference": "ChIJfYBLkWpWrlQRjig0x7oVFfk",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 121,
#             "vicinity": "350 N Milwaukee St, Boise"
#         }
#     ],
#     "status": "OK"
# }

# %%
# Print the name and address of the first restaurant that appears
print(places_data["results"][0]["name"])
print(places_data["results"][0]["vicinity"])
# Out:
# Guang Zhou Restaurant
# 7609 W Overland Rd, Boise

# %% [markdown]
# # Students Turn - 03 - Google Drills -  👩‍🎓👨‍🎓

# %% [markdown]
# # Google Drills
#
# In this activity we will perform API calls to the Google Places and Google Maps API.
#
# ## Instructions
#
# * Complete each of the six drills articulated in the code provided. Feel encouraged to look back at the previous examples but know that you will have to consult the Google API documentation.
#
# ### Hints
#
# * See the [Google Geocoding Documentation](https://developers.google.com/maps/documentation/geocoding/intro)
#
# * See the [Google Places Documentation](https://developers.google.com/maps/documentation/javascript/places#place_search_requests)
#
# * See the [Capping Queries](../../../Supplemental/Capping_Queries.md) document to set usage limits on your API calls.
#
# ---

# %%
# Create code to answer each of the following questions.
# Hint: You will need multiple target URLs and multiple API requests.

# Dependencies
import requests
import json

# Google API Key
from config import gkey

# 1. What are the geocoordinates (latitude/longitude) of Seattle, Washington?

# %%
# 2. What are the geocoordinates (latitude/longitude) of The White House?

# %%
# 3. Find the name and address of a bike store in Seattle, Washington.
#    Hint: See https://developers.google.com/places/web-service/supported_types

# %%
# 4. Find a balloon store near the White House.

# %%
# 5. Find the nearest dentist to your house.
#    Hint: Use Google Maps to find your latitude and Google Places to find the
#    dentist. You will also need the rankby property.

# %% [markdown]
# <details>
#     <summary><strong>Activity 03 Solution ✅</strong></summary>
#
# ```python
# # Create code to answer each of the following questions.
# # Hint: You will need multiple target URLs and multiple API requests.
#
# # Dependencies
# import requests
# import json
#
# # Google API Key
# from config import gkey
#
# # 1. What are the geocoordinates (latitude and longitude) of Seattle,
# # Washington?
# target_city = "Seattle, Washington"
#
# params = {"address": target_city, "key": gkey}
#
# # Build URL using the Google Maps API
# base_url = "https://maps.googleapis.com/maps/api/geocode/json"
#
# print("Drill #1: The Geocoordinates of Seattle, WA")
#
# # Run request
# response = requests.get(base_url, params=params)
#
# # Convert to JSON
# seattle_geo = response.json()
#
# # Extract lat/lng
# lat = seattle_geo["results"][0]["geometry"]["location"]["lat"]
# lng = seattle_geo["results"][0]["geometry"]["location"]["lng"]
#
# # Print results
# print(f"{target_city}: {lat}, {lng}")
#
# # 2. What are the geocoordinates (latitude and longitude) of The White House?
# # update params dict
# target_city = "The White House"
# params["address"] = target_city
#
#
# print("Drill #2: The Geocoordinates of the White House")
#
#
# # Run request
# response = requests.get(base_url, params=params)
#
# # print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
# # print(response.url)
#
# dc_geo = response.json()
# # Extract lat/lng
# lat = dc_geo["results"][0]["geometry"]["location"]["lat"]
# lng = dc_geo["results"][0]["geometry"]["location"]["lng"]
#
# # Print results
# print(f"{target_city}: {lat}, {lng}")
#
# # 3. Find the name and address of a bike store in Seattle, Washington.
# #    Hint: See https://developers.google.com/places/web-service/supported_types
# target_type = "bicycle_store"
# seattle_coords = "47.6062095,-122.3320708"
# radius = 8000
#
# # rewrite params dict
#
# params = {
#     "location": seattle_coords,
#     "types": target_type,
#     "radius": radius,
#     "key": gkey
# }
#
# # Build URL using the Google Maps API
# base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
#
# print("Drill #3: A Bike Store in Seattle, WA")
#
# # Run request
# response = requests.get(base_url, params)
#
# # print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
# # print(response.url)
#
# seattle_bikes = response.json()
#
# # Print the JSON (pretty printed)
# # print(json.dumps(seattle_bikes, indent=4, sort_keys=True))
#
# # Print the name and address of the first bike shop to appear
# print(seattle_bikes["results"][0]["name"])
# print(seattle_bikes["results"][0]["vicinity"])
#
# # 4. Find a balloon store near the White House.
# target_search = "Balloon Store"
# dc_coords = "38.8976763,-77.0365298"
#
# # redefine params
# params = {
#     "location": dc_coords,
#     "keyword": target_search,
#     "radius": radius,
#     "key": gkey
# }
#
# # Build URL using the Google Maps API
# base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
#
# print("Drill #4: A Balloon Store Near the White House")
#
# # Run request
# dc_balloons = requests.get(base_url, params).json()
#
# # Print the JSON (pretty printed)
# # print(json.dumps(dc_balloons, indent=4, sort_keys=True))
#
# # Print the name and address of the first balloon shop that appears
# print(dc_balloons["results"][0]["name"])
# print(dc_balloons["results"][0]["vicinity"])
#
# # 5. Find the nearest dentist to your house.
# # Hint: Use Google Maps to find your latitude and Google Places to find
# # the dentist. You may also need the rankby property.
#
# # Google geocode to find lat, lng
# my_address = "151 Sip Ave"
#
#
# params = {
#     "address": my_address,
#     "key": gkey
# }
#
# base_url = "https://maps.googleapis.com/maps/api/geocode/json"
#
# print("Drill #5: A Dentist Near My House")
#
# my_geo = requests.get(base_url, params).json()
#
# lat = my_geo["results"][0]["geometry"]["location"]["lat"]
# lng = my_geo["results"][0]["geometry"]["location"]["lng"]
#
#
# # Use lat, lng to use places API to find nearest dentist
# target_search = "dentist"
#
# params = {
#     "location": f"{lat},{lng}",
#     "types": target_search,
#     "rankby": "distance",
#     "key": gkey
# }
#
# base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
#
#
# # Run request
# response = requests.get(base_url, params)
#
# # print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
# # print(response.url)
# my_dentist = response.json()
#
# # Print the JSON (pretty printed)
# # print(json.dumps(my_dentist, indent=4, sort_keys=True))
#
# # Print the name and address of the first dentist that appears
# print(my_dentist["results"][0]["name"])
# print(my_dentist["results"][0]["vicinity"])
# ```
# </details>

# %% [markdown]
# # Instructor Turn - 04 - Nearest Restr - 👩‍🏫🧑‍🏫

# %%
# Dependencies
# Dependencies
import pandas as pd
import numpy as np
import requests
import json

# Google API Key
from config import gkey

# %%
types_df = pd.read_csv("./Resources/ethnic_restr.csv")
types_df.head()

# %%
# set up additional columns to hold information
types_df['name'] = ""
types_df['address'] = ""
types_df['price_level'] = ""
types_df['rating'] = ""

types_df.head()

# %%
# find the closest restaurant of each type to coordinates

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "location": "39.952583,-75.16522",  # philadelphia coords
    "rankby": "distance",
    "type": "restaurant",
    "key": gkey,
}
# use iterrows to iterate through pandas dataframe
for index, row in types_df.iterrows():

    # get restaurant type from df
    restr_type = row['ethnicity']

    # add keyword to params dict
    params['keyword'] = restr_type

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {restr_type}.")
    response = requests.get(base_url, params=params).json()
    
    # extract results
    results = response['results']
    
    try:
        print(f"Closest {restr_type} restaurant is {results[0]['name']}.")
        
        types_df.loc[index, 'name'] = results[0]['name']
        types_df.loc[index, 'address'] = results[0]['vicinity']
        types_df.loc[index, 'price_level'] = results[0]['price_level']
        types_df.loc[index, 'rating'] = results[0]['rating']
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")

# %%
types_df

# %% [markdown]
# # Instructor Turn - 05 - Google Complex (Airport)  - 👩‍🎓👨‍🎓
# # Google Complex (Airport)
#
# In this activity, you are tasked with creating a DataFrame containing the rating of every airport in the top 100 metropolitan areas according to Google Users.
#
# ## Instructions
#
# * Using cells below as a starting point, utilize the Google Geocoding API, the Google Places API, and Python/Jupyter to create a script that lists the "Airport Rating" of the major "International Airport" in each of the top 100 metropolitan areas found in(Resources/Cities.csv).
#
# *  Each of the following headers:
#
#   1. `City`
#
#   2. `State`
#
#   3. `Lat`
#
#   4. `Lng`
#
#   5. `Airport Name`
#
#   6. `Airport Address`
#
#   7. `Airport Rating`
#
# ### Hints
#
# * You will need to obtain the lat/lng of each airport prior to sending it through the Google Places API to obtain the rating.
#
# * When using the Google Places API, be sure to use the term "International Airport" to ensure that the data received is for the major airport in the city and not a regional airport.
#
# * Use a try-except to skip airports for which there are no Google user's ratings.
#
# ---

# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json

# Import API key

# Import cities file into the cities_pd DataFrame
cities_pd = pd.DataFrame()

# %%
# Add columns for lat, lng, airport name, airport address, airport rating.
# Hint: Be sure to specify "" as the initial value for each column.

# %%
# Loop through the cities_pd and get the lat/long for each city
# Hint: `requests.get(target_url).json()`
# Hint: `for index, row in cities_pd.iterrows():`
# Hint: `cities_pd.loc`

# %%
# Use the lat/lng we recovered to identify airports
# Hint: Code is similar to above block (i.e. you will need to use cities_pd.iterrows() again)
# Hint: Use the keyword search for "international+airport"
# Hint: Use a try-except to handle airports that are missing ratings

# Save Data to csv

# %% [markdown]
# <details>
#     <summary><strong>Activity 05 Solution ✅</strong></summary>
#
# ```python
#
# # Dependencies
# import pandas as pd
# import numpy as np
# import requests
# import json
#
# # Google API Key
# from config import gkey
#
# # Import cities file as DataFrame
# cities_pd = pd.read_csv("./Resources/Cities.csv")
# cities_pd.head()
#
# # Add columns for lat, lng, airport name, airport address, airport rating
# # Note that we used "" to specify initial entry.
# cities_pd["Lat"] = ""
# cities_pd["Lng"] = ""
# cities_pd["Airport Name"] = ""
# cities_pd["Airport Address"] = ""
# cities_pd["Airport Rating"] = ""
# cities_pd.head()
#
# # create a params dict that will be updated with new city each iteration
# params = {"key": gkey}
#
# # Loop through the cities_pd and run a lat/long search for each city
# for index, row in cities_pd.iterrows():
#     base_url = "https://maps.googleapis.com/maps/api/geocode/json"
#
#     city = row['City']
#     state = row['State']
#
#     # update address key value
#     params['address'] = f"{city},{state}"
#
#     # make request
#     cities_lat_lng = requests.get(base_url, params=params)
#
#     # print the cities_lat_lng url, avoid doing for public github repos in order to avoid exposing key
#     # print(cities_lat_lng.url)
#
#     # convert to json
#     cities_lat_lng = cities_lat_lng.json()
#
#     cities_pd.loc[index, "Lat"] = cities_lat_lng["results"][0]["geometry"]["location"]["lat"]
#     cities_pd.loc[index, "Lng"] = cities_lat_lng["results"][0]["geometry"]["location"]["lng"]
#
# # Visualize to confirm lat lng appear
# cities_pd.head()
#
# # params dictionary to update each iteration
# params = {
#     "radius": 50000,
#     "types": "airport",
#     "keyword": "international airport",
#     "key": gkey
# }
#
# # Use the lat/lng we recovered to identify airports
# for index, row in cities_pd.iterrows():
#     # get lat, lng from df
#     lat = row["Lat"]
#     lng = row["Lng"]
#
#     # change location each iteration while leaving original params in place
#     params["location"] = f"{lat},{lng}"
#
#     # Use the search term: "International Airport" and our lat/lng
#     base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
#
#     # make request and print url
#     name_address = requests.get(base_url, params=params)
#
# #     print the name_address url, avoid doing for public github repos in order to avoid exposing key
# #     print(name_address.url)
#
#     # convert to json
#     name_address = name_address.json()
#     # print(json.dumps(name_address, indent=4, sort_keys=True))
#
#     # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
#     try:
#         cities_pd.loc[index, "Airport Name"] = name_address["results"][0]["name"]
#         cities_pd.loc[index, "Airport Address"] = name_address["results"][0]["vicinity"]
#         cities_pd.loc[index, "Airport Rating"] = name_address["results"][0]["rating"]
#     except (KeyError, IndexError):
#         print("Missing field/result... skipping.")
#
# # Save Data to csv
# cities_pd.to_csv("Airport_Output.csv")
#
# # Visualize to confirm airport data appears
# cities_pd.head(10)
# ```
# </details>

# %% [markdown]
# # Instructor Turn - 06 - Gmaps - 👩‍🏫🧑‍🏫

# %%
# Notes pip install gmaps in terminal or anaconda prompt 
# also run jupyter nbextension enable --py gmaps in terminal or anaconda prompt then type jupyter notebooks 
# this will turn on the gmaps view for jupyter notebooks

# %%
# !pip install gmaps
# Out:
# Requirement already satisfied: gmaps in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (0.9.0)
# Requirement already satisfied: geojson>=2.0.0 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (2.5.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (7.6.5)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (7.29.0)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (5.1.1)
# Requirement already satisfied: six in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (1.16.0)
# Requirement already satisfied: matplotlib-inline in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.1.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (3.0.20)
# Requirement already satisfied: decorator in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (5.1.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.18.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (58.0.4)
# Requirement already satisfied: pygments in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (2.10.0)
# Requirement already satisfied: pickleshare in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: backcall in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: colorama in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.4.4)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (6.4.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.5.1)
# Requirement already satisfied: argcomplete>=1.12.3 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.12.3)
# Requirement already satisfied: importlib-metadata<5 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (4.8.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.12)
# Requirement already satisfied: zipp>=0.5 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from importlib-metadata<5->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from importlib-metadata<5->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (3.10.0.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->gmaps) (0.8.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (22.2.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (4.9.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (228)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.2.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.18.0)
# Requirement already satisfied: wcwidth in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.4.6)
# Requirement already satisfied: jinja2 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.3)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.8.0)
# Requirement already satisfied: argon2-cffi in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.1.0)
# Requirement already satisfied: prometheus-client in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.12.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.9.4)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.1)
# Requirement already satisfied: nbconvert in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.1.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.21)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: bleach in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (4.0.0)
# Requirement already satisfied: defusedxml in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.3)
# Requirement already satisfied: testpath in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: async-generator in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.10)
# Requirement already satisfied: packaging in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.3)
# Requirement already satisfied: webencodings in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\omaro\anaconda3\envs\pythondata\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.0.4)

# %%
# !jupyter nbextension enable --py gmaps
# Out:
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: ok

# %%
import gmaps

# Google developer API key
from config1 import gkey

# Access maps with unique API key
gmaps.configure(api_key=gkey)

# Create a list containing coordinates
coordinates = [
    (40.71, -74.00),
    (30.26, -97.74),
    (46.87, -96.78),
    (47.60, -122.33),
    (32.71, -117.16)
]

# Customize the size of the figure
figure_layout = {
    'width': '400px',
    'height': '300px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)

# Assign the marker layer to a variable
markers = gmaps.marker_layer(coordinates)
# Add the layer to the map
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…

# %% [markdown]
# # Student Turn - 07 - Hot Airport Reviews - 👩‍🎓👨‍🎓
#
#
# In this activity you will create a heatmap for ratings of airports.
#
# ## Instructions
#
# * If you haven't yet, navigate to your [Google Developer's Console](https://console.developers.google.com/) and enable the __Maps JavaScript API__.
#
# * Install `gmaps`
#
#
# * Using the cells below and the airport CSV in the Resources folder, create a heat map of the airports across the country.
#
#   * Use the latitude and longitude to place the airport
#
#   * Use the rating to weight the heatmap.
#
#   * Be sure to handle `NaN` values and data type in your Airport Ratings.
#
#   * Refer to the [gmaps documentation](http://jupyter-gmaps.readthedocs.io/en/latest/tutorial.html#heatmaps) for instructions on how to implement heatmaps.
#
#   ![Airport Heatmap](Images/08-Airport_Heatmap.png)
#
# ## BONUS
#
# * Explore the [documentation](http://jupyter-gmaps.readthedocs.io/en/latest/tutorial.html#base-maps) to plot the map as two more types of maps.
#
#   ![Hybrid Map](Images/08-Hybrid_Map.png)
#
#   ![Terrain Map](Images/08-Terrain_Map.png)
#
# ---

# %%
import gmaps
import pandas as pd

# Google developer API key
from config import gkey
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16684/59741299.py in <module>
#       3
#       4 # Google developer API key
# ----> 5 from config import gkey
#       6
#       7
#
# ModuleNotFoundError: No module named 'config'

# %%
# Create aiport dataframe

# %%
# Store latitude and longitude in locations

# %%
# Filla NaN values and convert to float

# %%
# Plot Heatmap

# %% [markdown]
# <details>
#     <summary><strong>Activity 07 Solution ✅</strong></summary>
#
# ```python
#
# # Configure gmaps
# gmaps.configure(api_key=gkey)
#
# # Create aiport dataframe
# airport_df = pd.read_csv('./Resources/Airport_Output.csv')
# airport_df.dropna(inplace = True)
# airport_df.head()
#
# # Store latitude and longitude in locations
# locations = airport_df[["Lat", "Lng"]]
#
# # Fill NaN values and convert to float
# rating = airport_df["Airport Rating"].astype(float)
#
# # Plot Heatmap
# fig = gmaps.figure()
#
# # Create heat layer
# heat_layer = gmaps.heatmap_layer(locations, weights=rating,
#                                  dissipating=False, max_intensity=10,
#                                  point_radius=1)
#
#
# # Add layer
# fig.add_layer(heat_layer)
#
# # Display figure
# fig
#
#
# # BONUS
# # Plost as a Hybrid map
# fig = gmaps.figure(map_type="HYBRID")
#
# # Create heat layer
# heat_layer = gmaps.heatmap_layer(locations, weights=rating,
#                                  dissipating=False, max_intensity=10,
#                                  point_radius=1)
#
# fig.add_layer(heat_layer)
# fig
#
#
# # BONUS
# # Plot as a Terrain map
# fig = gmaps.figure(map_type="TERRAIN")
#
# # Create heat layer
# heat_layer = gmaps.heatmap_layer(locations, weights=rating,
#                                  dissipating=False, max_intensity=10,
#                                  point_radius=1)
#
# fig.add_layer(heat_layer)
# fig
#
#
#
# ```
# </details>

# %% [markdown]
# # Instructor Turn - 08 - Itinerary - 👩‍🏫🧑‍🏫

# %%
# Dependencies and Setup
import pandas as pd
import gmaps

# Import API key
from config1 import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)

cities_df = pd.read_csv("./Resources/city.csv")
cities_df.head()
# Out:
#        City      Lat      Lng
# 0    Boston  42.3601 -71.0589
# 1  New York  40.7128 -74.0060
# 2   Chicago  41.8781 -87.6298

# %%
# Set the city to start and end your trip
city_start = cities_df.loc[cities_df["City"] == "Boston"]
city_end = cities_df.loc[cities_df["City"] == "Boston"]

# Set the cities to stop at
city_stop1 = cities_df.loc[cities_df["City"] == "New York"]
city_stop2 = cities_df.loc[cities_df["City"] == "Chicago"]

# Get the lat and lng for the start and end of the trip
start = city_start["Lat"].to_numpy()[0], city_start["Lng"].to_numpy()[0]
end = city_start["Lat"].to_numpy()[0], city_start["Lng"].to_numpy()[0]
print(f'Start: {start}, End: {end}')

# Get the lat and lng for the stops
coords_stop_1 = city_stop1["Lat"].to_numpy()[0], city_stop1["Lng"].to_numpy()[0]
coords_stop_2 = city_stop2["Lat"].to_numpy()[0], city_stop2["Lng"].to_numpy()[0]
print(f'Stop 1: {coords_stop_1}, Stop 2: {coords_stop_2}')

# Create Map with route
fig = gmaps.figure()
city_itinerary = gmaps.directions_layer(
        start, end, waypoints=[coords_stop_1, coords_stop_2],
        travel_mode='DRIVING')

fig.add_layer(city_itinerary)
fig
# Out:
# Start: (42.3601, -71.0589), End: (42.3601, -71.0589)
# Stop 1: (40.7128, -74.006), Stop 2: (41.8781, -87.6298)
# Figure(layout=FigureLayout(height='420px'))
